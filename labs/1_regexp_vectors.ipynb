# %% [markdown]
# # Text Analytics Lab 1: Regular Expressions and Vector Representations
#
# ### Learning Outcomes
# * Be able to set up a Python and Jupyter notebook environment for text analytics.
# * Understand how to use regular expressions to preprocess text.
# * Know how to carry out text normalisation including lemmatisation.
# * Know how to obtain bigram and TF-IDF vector representations of documents and term-document matrices.
# * Be able to compute cosine similarity to compare vector representations.
#
# ### Outline
#
# 1. Getting started: how to set up your environment, Jupyter notebooks introduction
# 1. Acquiring raw text data
# 1. Regular expressions
# 1. Text normalisation
# 1. Term-document matrices
# 1. Cosine Similarity
# 1. TF-IDF and bigram vectors
#
# ### How To Complete This Lab
#
# Read the text and the code then look for 'TODOs' that instruct you to complete some missing code. Look out for 'QUESTIONS' which you should try to answer before moving on to the next cell. Aim to work through the lab during the scheduled lab hours. To get help, you can talk to TAs or the lecturer during the labs, post questions to the Blackboard discussion board or on Teams, or ask a question in the lectures.
#
# The labs *will not be marked*. However, they will prepare you for the coursework, so try to keep up with the weekly labs and have fun with the exercises! Check the textbook (Jurafsky and Martin) for more information on the methods implemented here.
#
# ### Copilot and other AI tools
#
# If you are using an IDE like Visual Studio, we recommend switching off AI tools like Copilot while you are doing the lab. This is because the AI assistant will attempt to generate the answers for you -- sometimes it will be right, and you won't learn anything, and sometimes it will be wrong, and you'll just be confused!

# %% [markdown]
# ## 1. Getting Started
#
# ### Setting up your environment
#
# We recommend using ```conda``` to create an environment with the correct versions of all the packages you need for these labs. You can install either Anaconda or Miniconda, which will include the ```conda``` program.
#
# We provide a .yml file that lists all the packages you will need, and the versions that we have tested the labs with. You can use this file to create your environment as follows.
#
# 1. Open a terminal. Use the command line to navigate to the directory containing this notebook and the file ```crossplatform_environment.yml```. You can use the command ```cd``` to change directory on the command line.
#
# 1. For Lab machines only (e.g., in MVB 2.11 and QB 1.80): Load the Anaconda module: ```module load anaconda/3-2024```.
#
# 1. Run the conda program by typing ```conda env create -f crossplatform_environment.yml```, then answer any questions that appear on the command line.
#
# 1. Activate the environment by running the command ```conda activate text_analytics```.
#
# 1. Install some libraries that are not available through Conda: ```pip install bertopic umap-learn```.
#
# 1. Make kernel available in Jupyter: ```python -m ipykernel install --user --name=text_analytics```.
#
# 1. Relaunch Jupyter: shutdown any running instances, and then type ```jupyter lab``` into your command line.
#
# 1. Find this notebook and open it up again.
#
# 1. Go to the top menu and change the kernel: click on 'Kernel'--> 'Change kernel' --> text_analytics.
#
# You should now be ready to go!
#
# The core libraries we will be using in this unit are:
#
# - [Datasets](https://huggingface.co/docs/datasets/), produced by HuggingFace, is a hub for lots of interesting text datasets.
# - [NLTK](https://www.nltk.org), a comprehensive NLP library.
# - [Scikit-learn](https://scikit-learn.org/stable/user_guide.html), for machine learning and classifier evaluation.
# - [Gensim](https://radimrehurek.com/gensim/), for topic modelling.
# - [Transformers](https://huggingface.co/docs/transformers/en/index), for state-of-the-art NLP models.
# - [PyTorch](https://pytorch.org/), a framework for deep learning.
# - [BERTopic](https://maartengr.github.io/BERTopic/getting_started/quickstart/quickstart.html) for clustering documents into topics.
#
# The libraries above have good documentation, which is available either online (links above) or via Python itself, e.g. `help(numpy.array)` in the Python interpreter.
#
# ### Refreshers for Python and Jupyter
#
# If you need a refresher on Python, see the [Introduction to Python lab](https://github.com/UoB-COMS21202/lab_sheets_public/tree/master/lab_1) or the University of Bristol [Beginning Python](https://milliams.gitlab.io/beginning_python/) course. If you are a beginner with Python, you might also like to look at Chapter 1 in the NLTK book, which also provides a guide for "getting started with Python": https://www.nltk.org/book/.
#
# The labs will be run on [Jupyter Notebook](http://jupyter.org/), an interactive coding environment embedded in a webpage supporting various programing languages (Python, R, Lua, etc.) through the concept of kernels. The code in a notebook is arranged in _cells_. To edit an already existing cell simply double-click on it. Cells can be run by hitting `shift+enter` when editing a cell or by clicking on the `Run` button at the top. Create new cells with the keyboard shortcut `esc` followed by `A` or `B`.
#
# **Note**: when you run a code cell, all the created variables, implemented functions and imported libraries will be then available to every other code cell. It is commonly assumed that cells will be run in the correct sequence and running them repeatedly or out-of-order may sometimes cause errors. To reset all variables and functions (for debugging) simply click `Kernel > Restart` from the Jupyter menu.
#
# #### Markdown
#
# Markdown cells (like this one) allow you to write fancy comments in Markdown format - double click on this cell to see the source. An introduction to Markdown syntax can be found [here](https://daringfireball.net/projects/markdown/syntax). You can also display simple $\LaTeX$ equations in Markdown thanks to `MathJax` support: for inline equations wrap your equation between `$` symbols; for display mode equations use `$$`.

# %% [markdown]
# ## 1. Acquiring Raw Text Data
#
# Now, let's get some text data! [HuggingFace's datasets hub](https://huggingface.co/datasets) is a repository of many different text datasets: they are useful for experimenting with NLP tasks and training models. For this lab, we'll start with the IMDB dataset, which contains movie reviews along with their classification into "positive" or "negative" sentiment. Run the code below to download the data from [HuggingFace's datasets hub](https://huggingface.co/datasets/imdb):

# %%
import numpy as np
from datasets import load_dataset

cache_dir = "./data_cache"

# The data is already divided into training and test sets.
# Load the training set:
train_dataset = load_dataset(
    "imdb", # name of the dataset collection
    split="train",  # train or test
    cache_dir=cache_dir,
)
print(f"Training dataset with {len(train_dataset)} instances loaded")

train_dataset = np.random.choice(train_dataset, 100, replace=False)  # we'll only use a subset of the data in this lab so that the code runs quicker
# Out:
# Training dataset with 25000 instances loaded

# %% [markdown]
# We can access the documents in the dataset like elements in a list. For example, the document with index 3 looks like this:

# %%
train_dataset[5]
# Out:
# {'text': "This is what happens when you're living in China and the local video store is running thin on English-language titles\x97you are blessed with this work of what appears to be, yes, Romanian cinema. Nevertheless, I think that it has real comedic potential.<br /><br />Spoilers technically follow:<br /><br />Though I don't think that it would in fact spoil anyone's viewing pleasure to ask why a film set in a casino has a scene of beach archery, even in flashback. That mystery, and many other conundrums, remain to be exploited by desperate comedians, perhaps when they're stuck in Bucharest.<br /><br />Let me also wonder aloud why perfectly good-looking people allow themselves to abuse themselves on film like this. It's sad.",
#  'label': 0}

# %% [markdown]
# **TO-DO 1:** Print the label for document 31. What does the value mean?

# %%
#*** WRITE YOUR ANSWER HERE ***
train_dataset[31]['text']
# Out:
# 'This is high grade cheese fare of B movie kung fu flicks. Bruce "wannabe" Lee is played by Bruce Li...I think. Of course, let\'s show quick clips of Bruce and do closeups of his eyes and if you quint at the right angle during a certain time of the day during the winter solstice, it kind of looks like Bruce. You\'ll laugh in awe at how the film splicing isn\'t very good, but some cool deleted scenes from Enter the Dragon are thrown in the mix. According to the movie, Bruce Lee was killed by a dart while hanging from a helicopter. Of course, they think this can excuse Bruce Li for trying to be Bruce even though his character is supposed to be Bruce\'s brother (who for some reason still mimes Bruce\'s gestures and fighting style - very POORLY). See Bruce go one-on-one with the cowardly lion. The props department stopped by Kay-Bee, you see. Bruce also finds nothing wrong with savagely beating up a crippled man. Towards the end, the director decided "let\'s throw a flashback" for a scene just shown 3 minutes ago!! They must\'ve thought that only one-celled organisms with attention deficit disorder could fully understand this film.<br /><br />'

# %% [markdown]
# # 2. Regular Expressions
#
# In text analytics, we aim to retrieve or extract information from text documents, or classify or summarise documents to better understand a large amount of text. Typically, we are not just looking for a single word or phrase: that can be useful for retrieving documents given a keyword query, but there are many cases where we want to recognise more complex and variable patterns. For example, if we want to find dates, we cannot list all the possible combinations of digits we want to search for, but we can look for patterns of numbers in date format. To do this, we need a way to represent the patterns we are looking for inside a piece of text. The most direct way to represent text patterns is to use regular expressions. Regular expressions provide a standard language for writing text patterns, which we will learn about below.
#
# ## 2.1 Search
#
# We'll start by trying out some simple regular expressions. Suppose we want to identify tweets where people discuss really loved about certain movies. We could start by looking for tweets that contain the word 'love'. Before we try to look for more general patterns, a first step is just to look for all occurrences of the word 'love'. Review the code below to see how we can do this:

# %%
import re  # Python regular expressions library

all_matches = []

for review in train_dataset:
    matches = re.findall('love', review['text'])
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 48
# 48
# love

# %% [markdown]
# This has given us a list of matches in the variable `all_matches`, which all contain the string 'love', but not the sentences themselves.
# This isn't very useful, but we can do better if we define the right regular expression!
#
# Regular expressions represent patterns, rather than specific strings, allowing us to generalise our search and retrieve a many different strings that match the pattern.
# In Python, we differentiate a regular expression from a normal string by putting an 'r' character in front of the string.
#
# We can generalise our search by using a _disjunction_, which will match against any one of a set of characters. The disjunction is written inside square brackets.
#
# Let's try to retrieve instances of the word "love" followed by any letter. We can write a disjunction that matches any lower case letter as `[a-z]`:

# %%
all_matches = []

for review in train_dataset:
    matches = re.findall(r'love [a-z]', review['text'])
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 29
# 29
# love e
# love d
# love i
# love a
# love f
# love s
# love w
# love t
# love o
# love z
# love h

# %% [markdown]
# Our current search only matches a single letter of the word after 'love'. The length of that following word is variable, so how can we write an expression to match the whole word?
#
# Here, we can use a special character, '\*', which will match against zero or more repetitions of the preceding regular expression. Let's try it out:

# %%
all_matches = []

for review in train_dataset:
    matches = re.findall(r'love [a-z]*', review['text'])
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)

print(len(all_matches))  # length of the list of matches
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 29
# 29
# love about
# love interest
# love also
# love and
# love story
# love toward
# love with
# love his
# love of
# love song
# love dark
# love zombie
# love this
# love scenes
# love in
# love to
# love for
# love each
# love that
# love watching

# %% [markdown]
# Let's say we only want to retrieve the word following 'love', not the string containing 'love ' itself.
# We can do this using parentheses to create _groups_ of characters, such as this: `([a-z]*)`. The resulting matches will be returned as tuples of groups, and any characters not inside parentheses will not be returned as part of any group. Try out the code below to see this, and note that the space character after 'love' is not returned in the matches.

# %%
all_matches = []

for review in train_dataset:
    matches = re.findall(r'(love) ([a-z]*)', review['text'])
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match) 

for match in set(all_matches):  # just print the following
    print(match[1])
# Out:
# 29
# 29
# ('love', 'zombie')
# ('love', 'toward')
# ('love', 'also')
# ('love', 'for')
# ('love', 'watching')
# ('love', 'in')
# ('love', 'that')
# ('love', 'this')
# ('love', 'to')
# ('love', 'of')
# ('love', 'his')
# ('love', 'with')
# ('love', 'each')
# ('love', 'and')
# ('love', 'story')
# ('love', 'scenes')
# ('love', 'dark')
# ('love', 'about')
# ('love', 'interest')
# ('love', 'song')
# zombie
# toward
# also
# for
# watching
# in
# that
# this
# to
# of
# his
# with
# each
# and
# story
# scenes
# dark
# about
# interest
# song

# %% [markdown]
# Now, let's try to retrieve the preceding words as well. It would be better to match capital letters as well as lower case, which we can do with the disjunction `[a-zA-Z]`.
#
# **TO-DO 2:** complete the code below to retrieve only the words that precede and follow 'love', including capitalised and lower case words.

# %%
all_matches = []

for review in train_dataset:
    
    ### WRITE YOUR CODE HERE
    matches = re.findall(r'([a-zA-Z]*) (love)', review['text'])
    ########
    
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 45
# 45
# ('I', 'love')
# ('in', 'love')
# ('Young', 'love')
# ('trash', 'love')
# ('daughterly', 'love')
# ('genitals', 'love')
# ('ll', 'love')
# ('new', 'love')
# ('Hitler', 'love')
# ('he', 'love')
# ('his', 'love')
# ('about', 'love')
# ('her', 'love')
# ('tiring', 'love')
# ('young', 'love')
# ('would', 'love')
# ('is', 'love')
# ('their', 'love')
# ('secretly', 'love')
# ('true', 'love')
# ('the', 'love')
# ('s', 'love')
# ('friends', 'love')
# ('and', 'love')
# ('still', 'love')
# ('', 'love')

# %% [markdown]
# This is starting to look more useful, but we still want to retrieve whole sentences.
#
# Sentences in English are usually demarcated by punctuation (this is not the same for languages in other scripts, such as Chinese, Hindi and Thai). As we're working with English text only at the moment, let's use the following punctuation marks to identify sentence boundaries: '.', '!', '?'. In the regular expression language, those punctuation marks are special characters that do not literally represent the symbols '.', '!', or '?'. To force Python to interpret them literally, we need to put the escape character '\\' in front of them.
#
# Now, we can write a disjunction that matches against the punctuation like this: `[\.\!\?]`.
#
# So far, we have assumed the text consists only of letters. Can you think of any characters we have excluded here?
#
# It can be hard to list every character we want to match. A better way to find all matches could be to use _negation_ to match against any character _except_ the punctuation marks that bound the sentences. A negation will match any character except those specified, which we can write like this: `[^\.\!\?]`, where the '^' indicates the negation.
#
#
# **TO-DO 3:** Retrieve whole sentences containing 'love'. To do this, modify our previous expression by using negation to match all of the characters except '.', '!', and '?'.

# %%
all_matches = []

for review in train_dataset:
    
    ### WRITE YOUR CODE HERE
    matches = re.findall(r'', review['text'])
    ########

    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 1695
# !
# .
# ?

# %% [markdown]
# Look at the results -- does the regular expression correctly return sentences containing 'love'?
#
# There are lots more special characters that you can use to form really powerful regular expressions for segmenting, retrieving and substituting text. For your reference, you can find a complete list [here](https://docs.python.org/3/library/re.html#regular-expression-syntax). You can take a look at this list and try to rewrite the expressions above in different ways using the special characters.

# %% [markdown]
# ## 2.2 Substitution
#
# Besides matching and retrieving pieces of text, regular expressions can also be used to alter text by substituting one string for another. There are many potential uses, for example, to fill in templates by replacing placeholders with dates, filenames or other information. For example, imagine a system for sending automated reminders of doctor's appointments. It may contain a sentence "This is to remind you of your appointment on DATE at TIME.". Substitution can be used to replace the strings 'DATE' and 'TIME' with specifica values.
#
# Regular expression _substitution_ finds a matching string within a larger piece of text, and replaces it with another string.
#
# Let's use this to clean up the text by removing the line break characters.
#
# In Python, we can use the re.sub() function, which takes three arguments:
# 1. The expression to match.
# 2. The pattern we should replace it with
# 3. The text to apply the subtitution to.
#
# Some of the reviews contain some HTML formatting code, `<br />`, which we can try to remove to clean up the text. We can do this by writing an expression for the first argument of re.sub() that matches '<br />'. Take a look at how this works by running the code below:

# %%
print('ORIGINAL TEXT: ')
print(train_dataset[5]['text'])
    
clean_article = re.sub(r'<br />', r' ', train_dataset[5]['text'])  # replace HTML breaks with a space
    
print('CLEANER TEXT: ')
print(clean_article)
# Out:
# ORIGINAL TEXT:
# This is what happens when you're living in China and the local video store is running thin on English-language titlesyou are blessed with this work of what appears to be, yes, Romanian cinema. Nevertheless, I think that it has real comedic potential.<br /><br />Spoilers technically follow:<br /><br />Though I don't think that it would in fact spoil anyone's viewing pleasure to ask why a film set in a casino has a scene of beach archery, even in flashback. That mystery, and many other conundrums, remain to be exploited by desperate comedians, perhaps when they're stuck in Bucharest.<br /><br />Let me also wonder aloud why perfectly good-looking people allow themselves to abuse themselves on film like this. It's sad.
# CLEANER TEXT:
# This is what happens when you're living in China and the local video store is running thin on English-language titlesyou are blessed with this work of what appears to be, yes, Romanian cinema. Nevertheless, I think that it has real comedic potential.  Spoilers technically follow:  Though I don't think that it would in fact spoil anyone's viewing pleasure to ask why a film set in a casino has a scene of beach archery, even in flashback. That mystery, and many other conundrums, remain to be exploited by desperate comedians, perhaps when they're stuck in Bucharest.  Let me also wonder aloud why perfectly good-looking people allow themselves to abuse themselves on film like this. It's sad.

# %% [markdown]
# # 3. Text Normalisation
#
# For most text analytics tasks, such as document classification, we will first need to transform the raw text to a suitable format for input to method such as a classifier. This process is called _text normalisation_ and is part of the _preprocessing_ stage. There are three common steps:
#
# 1. Sentence segmentation: this is needed when we want to process each sentence separately, e.g., to classify its sentiment. We have already tried out a basic approach to obtaining complete sentences using regular expressions. This would need to be modified to return a list of all sentences in a document.
# 2. Tokenisation, in which the sentences are split into a sequence of tokens, which include words, numbers and punctuation marks.
# 3. Word normalisation, in which different forms of a word are replaced by a root form. Many text analytics models, such as document classifiers, can benefit from words being _normalised_ to consistent word forms (e.g., "dog", "Dog" and "dogs" could all normalised to "dog"), as this can reduce the diversity of the vocabulary make it easier to find meaningful patterns in the data.
#
# We are now going to see how to perform these steps using the NLTK library.
#
# ## 3.1 Sentence Segmentation
#
# Let's start by using NLTK to split a document into sentences. This should give better results than our regular expressions above.
#
# You may get some errors from NLTK when you try to use sent_tokenize or word_tokenize further down. This is usually because you need to download and install some NLTK data. Please check the error message to find out which package is required. You probably need to install packages called 'punkt' and 'wordnet'. You can install these packages by running the cell below.

# %%
import nltk 

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ksstu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ksstu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ksstu\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk

review = train_dataset[5]['text']

sents = nltk.sent_tokenize(review)

for sent in sents:
    print("<SENTENCE>")
    print(sent)  # print the sentences of this document
# Out:
# <SENTENCE>
# This is what happens when you're living in China and the local video store is running thin on English-language titlesyou are blessed with this work of what appears to be, yes, Romanian cinema.
# <SENTENCE>
# Nevertheless, I think that it has real comedic potential.<br /><br />Spoilers technically follow:<br /><br />Though I don't think that it would in fact spoil anyone's viewing pleasure to ask why a film set in a casino has a scene of beach archery, even in flashback.
# <SENTENCE>
# That mystery, and many other conundrums, remain to be exploited by desperate comedians, perhaps when they're stuck in Bucharest.<br /><br />Let me also wonder aloud why perfectly good-looking people allow themselves to abuse themselves on film like this.
# <SENTENCE>
# It's sad.

# %% [markdown]
# **TO-DO 4:** Use the regular expression substitution code from section 2.2 to remove the '\<br /\>' tags from the sentences displayed above and print the results.

# %%
clean_sents = []

for sent in sents:
    
    ### WRITE YOUR OWN CODE HERE
    sent = re.sub(r'<br />', r' ', sent)  # replace HTML breaks with a space
    #######
    
    print("<SENTENCE>")
    print(sent)  # print the sentences of this document
    
    clean_sents.append(sent)  # save the cleaned sentences for later
# Out:
# <SENTENCE>
# This is what happens when you're living in China and the local video store is running thin on English-language titlesyou are blessed with this work of what appears to be, yes, Romanian cinema.
# <SENTENCE>
# Nevertheless, I think that it has real comedic potential.  Spoilers technically follow:  Though I don't think that it would in fact spoil anyone's viewing pleasure to ask why a film set in a casino has a scene of beach archery, even in flashback.
# <SENTENCE>
# That mystery, and many other conundrums, remain to be exploited by desperate comedians, perhaps when they're stuck in Bucharest.  Let me also wonder aloud why perfectly good-looking people allow themselves to abuse themselves on film like this.
# <SENTENCE>
# It's sad.

# %% [markdown]
# ## 3.2 Tokenisation
#
# NLTK provides a similar function for tokenizing the text at the word level. You can find the documentation [here](https://www.nltk.org/api/nltk.tokenize.html). Most tokenizers use either regular expressions or a machine learning model that was trained on a large dataset to learn token-splitting rules.
#
# **TO-DO 5:** Use word_tokenize() to tokenize each of the sentences from the last cell.

# %%
tokenized_sents = []

for sent in clean_sents:
    ### WRITE YOUR OWN CODE HERE
    tokens = nltk.word_tokenize(sent)
    #######
    
    print("<TOKENS>")
    print(tokens)
    
    tokenized_sents.append(tokens)
# Out:
# <TOKENS>
# ['This', 'is', 'what', 'happens', 'when', 'you', "'re", 'living', 'in', 'China', 'and', 'the', 'local', 'video', 'store', 'is', 'running', 'thin', 'on', 'English-language', 'titles\x97you', 'are', 'blessed', 'with', 'this', 'work', 'of', 'what', 'appears', 'to', 'be', ',', 'yes', ',', 'Romanian', 'cinema', '.']
# <TOKENS>
# ['Nevertheless', ',', 'I', 'think', 'that', 'it', 'has', 'real', 'comedic', 'potential', '.', 'Spoilers', 'technically', 'follow', ':', 'Though', 'I', 'do', "n't", 'think', 'that', 'it', 'would', 'in', 'fact', 'spoil', 'anyone', "'s", 'viewing', 'pleasure', 'to', 'ask', 'why', 'a', 'film', 'set', 'in', 'a', 'casino', 'has', 'a', 'scene', 'of', 'beach', 'archery', ',', 'even', 'in', 'flashback', '.']
# <TOKENS>
# ['That', 'mystery', ',', 'and', 'many', 'other', 'conundrums', ',', 'remain', 'to', 'be', 'exploited', 'by', 'desperate', 'comedians', ',', 'perhaps', 'when', 'they', "'re", 'stuck', 'in', 'Bucharest', '.', 'Let', 'me', 'also', 'wonder', 'aloud', 'why', 'perfectly', 'good-looking', 'people', 'allow', 'themselves', 'to', 'abuse', 'themselves', 'on', 'film', 'like', 'this', '.']
# <TOKENS>
# ['It', "'s", 'sad', '.']

# %% [markdown]
# Run the code below to see how NLTK has handled the non-letter characters.
# * What does it do with most punctuation marks?
# * When does it not split tokens based on punctuation?

# %%
for sent in tokenized_sents:
    for tok in sent:
        if re.search(r'[^a-zA-Z0-9]', tok):  # find the non-letter and non-digit characters
            print(tok)  # print the entire token containing the non-letter/non-digit character
# Out:
# 're
# English-language
# titlesyou
# ,
# ,
# .
# ,
# .
# :
# n't
# 's
# ,
# .
# ,
# ,
# ,
# 're
# .
# good-looking
# .
# 's
# .

# %% [markdown]
# ## 3.3 Word Normalisation
#
# Many words can appear in different forms, including:
# * Conjugated verbs like "think", "thinks" and "thought",
# * Plural and singular nouns like "dog" and "dogs",
# * Common abbrevations and synonyms like "USA" and "US".
#
# Mapping all of these surface forms to a single root form reduces the size of the vocabulary that we have to deal with and can therefore improve the performance of text classifiers or topic models.
#
# The two most widely used tools for this task in English are the Porter Stemmer and WordNet Lemmatizer. These tools apply a series of regular expression substitutions to tokenised text to convert words to a standard format.
# * The Porter stemmer is much faster but just removes word prefixes and endings, which leads to some errors. It is often used when real-time or high-volume text processing is needed.
# * As well as applying regular expressions, lemmatizers look words up in a dictionary to find their root forms, so are more accurate but much slower.
#
# Let's start by applying the [Porter Stemmer class](https://www.nltk.org/_modules/nltk/stem/porter.html) to our tokenised text by calling the stem() method. The output may look a bit strange, but note that the aim of the stemmer is *not* to produce readable text, but to quickly and efficiently reduce variations of words to a single form.

# %%
stemmer = nltk.PorterStemmer() 
stemmed_sents = []

for sent in tokenized_sents:
    stemmed_sent = [stemmer.stem(tok) for tok in sent]
    
    stemmed_sents.append(stemmed_sent)
    
    print("<STEMMED TOKENS>")
    print(stemmed_sent)
# Out:
# <STEMMED TOKENS>
# ['thi', 'is', 'what', 'happen', 'when', 'you', "'re", 'live', 'in', 'china', 'and', 'the', 'local', 'video', 'store', 'is', 'run', 'thin', 'on', 'english-languag', 'titles\x97y', 'are', 'bless', 'with', 'thi', 'work', 'of', 'what', 'appear', 'to', 'be', ',', 'ye', ',', 'romanian', 'cinema', '.']
# <STEMMED TOKENS>
# ['nevertheless', ',', 'i', 'think', 'that', 'it', 'ha', 'real', 'comed', 'potenti', '.', 'spoiler', 'technic', 'follow', ':', 'though', 'i', 'do', "n't", 'think', 'that', 'it', 'would', 'in', 'fact', 'spoil', 'anyon', "'s", 'view', 'pleasur', 'to', 'ask', 'whi', 'a', 'film', 'set', 'in', 'a', 'casino', 'ha', 'a', 'scene', 'of', 'beach', 'archeri', ',', 'even', 'in', 'flashback', '.']
# <STEMMED TOKENS>
# ['that', 'mysteri', ',', 'and', 'mani', 'other', 'conundrum', ',', 'remain', 'to', 'be', 'exploit', 'by', 'desper', 'comedian', ',', 'perhap', 'when', 'they', "'re", 'stuck', 'in', 'bucharest', '.', 'let', 'me', 'also', 'wonder', 'aloud', 'whi', 'perfectli', 'good-look', 'peopl', 'allow', 'themselv', 'to', 'abus', 'themselv', 'on', 'film', 'like', 'thi', '.']
# <STEMMED TOKENS>
# ['it', "'s", 'sad', '.']

# %% [markdown]
# Now let's compare the stemming results to lemmatisation. For this task, NLTK provides the [class WordNetLemmatizer](https://www.nltk.org/_modules/nltk/stem/wordnet.html) with the method lemmatize(). This method takes an argument, `pos`, that determines whether the lemmatizer is applied to nouns, verbs, adjectives or adverbs.
#
# **TO-DO 6:** Use the WordNetLemmatizer to lemmatize the nouns in the tokenized sentences. Set the `pos` argument to 'n'.
#
# **TO-DO 7:** Add a second call to lemmatize() to lemmatize the verbs in the sentences as well. Set the `pos` argument to 'v'.
#
# How do the results compare with the Porter stemmer?
#
# How have the verbs in the sentences changed?

# %%
lemmatizer = nltk.WordNetLemmatizer() 
lemma_sents = []
for sent in tokenized_sents:
    
    ### WRITE YOUR OWN CODE HERE
    lemma_sent = [lemmatizer.lemmatize(token, pos='n') for token in sent]
    lemma_verb_sent = [lemmatizer.lemmatize(token, pos='v') for token in sent]
    #######
    
    lemma_sents.append(lemma_sent)
    
    print("<LEMMATIZED TOKENS>")
    print(lemma_sent)
    print("<LEMMATIZED VERB TOKENS>")
    print(lemma_verb_sent)
# Out:
# <LEMMATIZED TOKENS>
# ['This', 'is', 'what', 'happens', 'when', 'you', "'re", 'living', 'in', 'China', 'and', 'the', 'local', 'video', 'store', 'is', 'running', 'thin', 'on', 'English-language', 'titles\x97you', 'are', 'blessed', 'with', 'this', 'work', 'of', 'what', 'appears', 'to', 'be', ',', 'yes', ',', 'Romanian', 'cinema', '.']
# <LEMMATIZED VERB TOKENS>
# ['This', 'be', 'what', 'happen', 'when', 'you', "'re", 'live', 'in', 'China', 'and', 'the', 'local', 'video', 'store', 'be', 'run', 'thin', 'on', 'English-language', 'titles\x97you', 'be', 'bless', 'with', 'this', 'work', 'of', 'what', 'appear', 'to', 'be', ',', 'yes', ',', 'Romanian', 'cinema', '.']
# <LEMMATIZED TOKENS>
# ['Nevertheless', ',', 'I', 'think', 'that', 'it', 'ha', 'real', 'comedic', 'potential', '.', 'Spoilers', 'technically', 'follow', ':', 'Though', 'I', 'do', "n't", 'think', 'that', 'it', 'would', 'in', 'fact', 'spoil', 'anyone', "'s", 'viewing', 'pleasure', 'to', 'ask', 'why', 'a', 'film', 'set', 'in', 'a', 'casino', 'ha', 'a', 'scene', 'of', 'beach', 'archery', ',', 'even', 'in', 'flashback', '.']
# <LEMMATIZED VERB TOKENS>
# ['Nevertheless', ',', 'I', 'think', 'that', 'it', 'have', 'real', 'comedic', 'potential', '.', 'Spoilers', 'technically', 'follow', ':', 'Though', 'I', 'do', "n't", 'think', 'that', 'it', 'would', 'in', 'fact', 'spoil', 'anyone', "'s", 'view', 'pleasure', 'to', 'ask', 'why', 'a', 'film', 'set', 'in', 'a', 'casino', 'have', 'a', 'scene', 'of', 'beach', 'archery', ',', 'even', 'in', 'flashback', '.']
# <LEMMATIZED TOKENS>
# ['That', 'mystery', ',', 'and', 'many', 'other', 'conundrum', ',', 'remain', 'to', 'be', 'exploited', 'by', 'desperate', 'comedian', ',', 'perhaps', 'when', 'they', "'re", 'stuck', 'in', 'Bucharest', '.', 'Let', 'me', 'also', 'wonder', 'aloud', 'why', 'perfectly', 'good-looking', 'people', 'allow', 'themselves', 'to', 'abuse', 'themselves', 'on', 'film', 'like', 'this', '.']
# <LEMMATIZED VERB TOKENS>
# ['That', 'mystery', ',', 'and', 'many', 'other', 'conundrums', ',', 'remain', 'to', 'be', 'exploit', 'by', 'desperate', 'comedians', ',', 'perhaps', 'when', 'they', "'re", 'stick', 'in', 'Bucharest', '.', 'Let', 'me', 'also', 'wonder', 'aloud', 'why', 'perfectly', 'good-looking', 'people', 'allow', 'themselves', 'to', 'abuse', 'themselves', 'on', 'film', 'like', 'this', '.']
# <LEMMATIZED TOKENS>
# ['It', "'s", 'sad', '.']
# <LEMMATIZED VERB TOKENS>
# ['It', "'s", 'sad', '.']

# %% [markdown]
# # 5. Vector Representations of Text

# %% [markdown]
# Regular expressions are great for tasks such as finding specific patterns in text. However, it is not always possible to write a regular expression that captures all the patterns we want to find. For example, suppose we want to classify social media posts into positive and negative sentiment to see if they are favourable towards a particular famous person. We can't write down a pattern to capture all the ways of saying favourable things about that person -- it's way too diverse.
#
# Instead, we can use machine learning to learn to recognise a wide range of patterns from a set of examples. To classify a new example, a machine learning classifier requires a *representation* of each piece of text that it can compare against the patterns it has learned. Raw text is not usually a suitable representation, and we usually need a way to turn text data into vectors -- essentially, lists of numbers. Vector representations have several advantages: for example, they map words, sentences and documents to points in a high-dimensional space, so we can learn to separate the space into different regions corresponding to classes; they allow us to compute the similarity between pieces of text by computing distances.
#
# In this section, we'll loook at the simplest way to obtain vector representations of words and documents by constructing a *term-document matrix*. A term-document matrix has rows referring to terms, and columns referring to documents. Each element contains a count of how many times a particular term occurred in a particular document. We can treat rows as vector representations of terms, and columns as vector representations of documents.
#
# To compute term-document matrices, we need to use the text normalisation steps above. Most importantly, we need to tokenise the text into words (and other types of token) so we can count their occurrences. Normalising the words is often helpful too, as it reduces the number of rows in the matrix and makes it less sparse.
#
# We can compute a term-document matrix using the CountVectorizer class from Scikit-learn. By default, this class takes raw text sequences and applies an English tokenizer automatically:

# %%
from sklearn.feature_extraction.text import CountVectorizer

input_text = [review['text'] for review in train_dataset]  # use a list of sentences as an example. 

vectorizer = CountVectorizer()
vectorizer.fit(input_text)
# Out:
# CountVectorizer()

# %% [markdown]
# Have you seen the method "fit()" before with other Scikit-learn classes? What do you think it does for the CountVectorizer?
#
# Looking inside the vectorizer, we can see the vocabulary it has created from the input text:

# %%
vectorizer.vocabulary_
# Out:
# {'didn': 1271,
#  'care': 717,
#  'for': 1781,
#  'the': 4387,
#  'movie': 2910,
#  'book': 563,
#  'was': 4760,
#  'better': 494,
#  'does': 1348,
#  'anyone': 256,
#  'know': 2493,
#  'where': 4818,
#  'it': 2370,
#  'filmed': 1711,
#  'this': 4410,
#  'my': 2936,
#  'first': 1732,
#  'visit': 4711,
#  'to': 4446,
#  'your': 4936,
#  'site': 4011,
#  'just': 2432,
#  'found': 1810,
#  'answer': 247,
#  'question': 3479,
#  'so': 4048,
#  'now': 3035,
#  'look': 2650,
#  'like': 2598,
#  'dummy': 1399,
#  'but': 665,
#  'think': 4406,
#  'll': 2622,
#  'still': 4168,
#  'submit': 4232,
#  'comments': 928,
#  'and': 226,
#  'yes': 4930,
#  'british': 614,
#  'columbia': 908,
#  'is': 2359,
#  'lovely': 2668,
#  'or': 3104,
#  'why': 4833,
#  'they': 4402,
#  'took': 4462,
#  'from': 1841,
#  'its': 2375,
#  'south': 4088,
#  'carolina': 727,
#  'coastal': 890,
#  'setting': 3903,
#  'stands': 4144,
#  'place': 3270,
#  'essential': 1538,
#  'fabric': 1621,
#  'of': 3062,
#  'change': 781,
#  'part': 3167,
#  'disappointment': 1294,
#  'with': 4869,
#  'oh': 3074,
#  'read': 3523,
#  'need': 2976,
#  'write': 4908,
#  'at': 340,
#  'least': 2552,
#  'ten': 4361,
#  'lines': 2604,
#  'here': 2093,
#  'other': 3116,
#  'main': 2705,
#  'issue': 2367,
#  'film': 1710,
#  'kim': 2473,
#  'bassinger': 420,
#  'too': 4461,
#  'vapid': 4673,
#  'not': 3024,
#  'all': 187,
#  'what': 4812,
#  'pictured': 3249,
#  'well': 4803,
#  'good': 1947,
#  'character': 788,
#  'in': 2240,
#  'much': 2917,
#  'more': 2888,
#  'empathetic': 1472,
#  'also': 200,
#  'evoked': 1564,
#  'rustic': 3752,
#  'almost': 193,
#  'primitive': 3396,
#  'images': 2215,
#  'monastery': 2872,
#  'while': 4821,
#  'castle': 744,
#  'visually': 4714,
#  'impressive': 2236,
#  'distorted': 1334,
#  'feel': 1676,
#  'story': 4183,
#  'seemed': 3854,
#  'odds': 3060,
#  'characters': 791,
#  'vampyres': 4670,
#  'br': 585,
#  'aspect': 323,
#  'ratio': 3513,
#  '85': 60,
#  'sound': 4084,
#  'format': 1798,
#  'mono': 2879,
#  'motorist': 2904,
#  'murray': 2928,
#  'brown': 626,
#  'lured': 2683,
#  'an': 223,
#  'isolated': 2364,
#  'country': 1041,
#  'house': 2168,
#  'inhabited': 2280,
#  'by': 672,
#  'two': 4553,
#  'beautiful': 445,
#  'young': 4934,
#  'women': 4881,
#  'marianne': 2736,
#  'morris': 2895,
#  'anulka': 252,
#  'becomes': 451,
#  'enmeshed': 1504,
#  'their': 4390,
#  'free': 1825,
#  'spirited': 4108,
#  'sexual': 3909,
#  'lifestyle': 2591,
#  'his': 2118,
#  'hosts': 2162,
#  'turn': 4544,
#  'out': 3120,
#  'be': 433,
#  'vampires': 4669,
#  'frenzied': 1830,
#  'lust': 2685,
#  'human': 2178,
#  'blood': 540,
#  'taking': 4325,
#  'cue': 1100,
#  'lesbian': 2570,
#  'vampire': 4668,
#  'cycle': 1117,
#  'initiated': 2284,
#  'maverick': 2765,
#  'director': 1286,
#  'jean': 2387,
#  'rollin': 3717,
#  'france': 1815,
#  'consolidated': 987,
#  'success': 4241,
#  'hammer': 2015,
#  'carmilla': 725,
#  'series': 3890,
#  'uk': 4562,
#  'jose': 2416,
#  'ramon': 3499,
#  'larraz': 2524,
#  'daring': 1138,
#  'shocker': 3951,
#  'pushed': 3466,
#  'concept': 954,
#  'adult': 134,
#  'horror': 2157,
#  'further': 1858,
#  'than': 4381,
#  'censors': 765,
#  'were': 4808,
#  'prepared': 3367,
#  'tolerate': 4452,
#  '1974': 28,
#  'cut': 1113,
#  'three': 4419,
#  'minutes': 2843,
#  'on': 3082,
#  'original': 3110,
#  'release': 3587,
#  'isn': 2363,
#  'difficult': 1277,
#  'see': 3847,
#  'using': 4656,
#  'gothic': 1954,
#  'theme': 4393,
#  'as': 312,
#  'pretext': 3385,
#  'nudity': 3037,
#  'sex': 3908,
#  'bloodshed': 541,
#  'short': 3958,
#  'running': 3749,
#  'time': 4437,
#  'will': 4840,
#  'allow': 189,
#  'who': 4827,
#  'wrote': 4916,
#  'screenplay': 3821,
#  'under': 4572,
#  'pseudonym': 3444,
#  'daubeney': 1146,
#  'uses': 4655,
#  'these': 4400,
#  'commercial': 929,
#  'elements': 1453,
#  'mere': 2803,
#  'backdrop': 386,
#  'languid': 2520,
#  'meditation': 2786,
#  'life': 2589,
#  'death': 1164,
#  'impulses': 2238,
#  'otherwise': 3118,
#  'which': 4820,
#  'affirm': 146,
#  'condition': 962,
#  'shot': 3961,
#  'location': 2632,
#  'picturesque': 3251,
#  'during': 1401,
#  'autumn': 366,
#  '1973': 27,
#  'harry': 2043,
#  'waxman': 4775,
#  'haunting': 2055,
#  'cinematography': 840,
#  'conjures': 977,
#  'atmosphere': 341,
#  'grim': 1978,
#  'foreboding': 1785,
#  'desolate': 1235,
#  'countryside': 1042,
#  'bleak': 527,
#  'equal': 1524,
#  'measure': 2779,
#  'seems': 3856,
#  'foreshadow': 1787,
#  'whirlwind': 4825,
#  'impending': 2224,
#  'pulled': 3455,
#  'similar': 3990,
#  'trick': 4515,
#  'earlier': 1413,
#  'same': 3768,
#  'year': 4924,
#  'symptoms': 4317,
#  'low': 2673,
#  'key': 2459,
#  'thriller': 4420,
#  'erupts': 1533,
#  'into': 2333,
#  'frenzy': 1831,
#  'violence': 4704,
#  'final': 1718,
#  'reel': 3563,
#  'however': 2171,
#  'despite': 1239,
#  'pretensions': 3383,
#  'wafer': 4727,
#  'thin': 4403,
#  'plot': 3293,
#  'rough': 3733,
#  'hewn': 2102,
#  'production': 3417,
#  'values': 4667,
#  'divide': 1341,
#  'audiences': 357,
#  'outset': 3125,
#  'female': 1683,
#  'protagonists': 3431,
#  'are': 286,
#  'charismatic': 794,
#  'appealing': 268,
#  'could': 1035,
#  'wished': 4864,
#  'male': 2714,
#  'lead': 2543,
#  'past': 3180,
#  'prime': 3395,
#  'filming': 1712,
#  'woefully': 4876,
#  'miscast': 2846,
#  'role': 3713,
#  'that': 4385,
#  'should': 3963,
#  'have': 2056,
#  'gone': 1945,
#  'some': 4066,
#  'twentysomething': 4549,
#  'stud': 4213,
#  'must': 2933,
#  'item': 2373,
#  'cult': 1101,
#  'fans': 1651,
#  'amusing': 222,
#  'curio': 1104,
#  'everyone': 1558,
#  'else': 1461,
#  'acquired': 101,
#  'taste': 4338,
#  'watch': 4767,
#  'silent': 3987,
#  'era': 1528,
#  'superstar': 4272,
#  'bessie': 490,
#  'love': 2666,
#  'brief': 605,
#  'cameo': 686,
#  'end': 1478,
#  'interesting': 2322,
#  'naive': 2944,
#  'park': 3165,
#  'ranger': 3504,
#  'colin': 897,
#  'firth': 1733,
#  'marries': 2747,
#  'pretty': 3386,
#  'mysterious': 2939,
#  'woman': 4879,
#  'lisa': 2608,
#  'zane': 4939,
#  'he': 2061,
#  'only': 3088,
#  'known': 2496,
#  'seem': 3853,
#  'happy': 2034,
#  'then': 4396,
#  'she': 3932,
#  'disappears': 1290,
#  'without': 4870,
#  'warning': 4754,
#  'searches': 3832,
#  'her': 2091,
#  'after': 154,
#  'few': 1693,
#  'dead': 1158,
#  'ends': 1484,
#  'stumbles': 4222,
#  'upon': 4641,
#  'abused': 82,
#  'childhood': 814,
#  'sleazy': 4026,
#  'recent': 3543,
#  'may': 2766,
#  'include': 2247,
#  'criminal': 1082,
#  'activity': 109,
#  'filmmakers': 1714,
#  'do': 1343,
#  'beginning': 462,
#  'suspenseful': 4300,
#  'sounds': 4086,
#  'watchable': 4768,
#  'ceases': 758,
#  'even': 1552,
#  'make': 2709,
#  'sense': 3873,
#  'ending': 1483,
#  'lame': 2511,
#  'dull': 1397,
#  'devoid': 1258,
#  'any': 254,
#  'excitement': 1575,
#  'intelligence': 2311,
#  'you': 4933,
#  'screenwriters': 3823,
#  'got': 1953,
#  'bored': 567,
#  'trying': 4534,
#  'sorry': 4080,
#  'waste': 4764,
#  'idea': 2197,
#  'been': 456,
#  'episode': 1520,
#  'simply': 3995,
#  'had': 2003,
#  'off': 3063,
#  'representation': 3624,
#  'horrible': 2156,
#  'makers': 2710,
#  'ever': 1555,
#  'set': 3901,
#  'foot': 1779,
#  'britain': 613,
#  'prior': 3402,
#  'england': 1492,
#  'don': 1358,
#  'person': 3222,
#  'such': 4244,
#  'accent': 83,
#  'apart': 261,
#  'comedy': 916,
#  'skit': 4021,
#  'royal': 3740,
#  'family': 1646,
#  'english': 1493,
#  'boys': 584,
#  'boy': 582,
#  'has': 2046,
#  'acted': 105,
#  'spoke': 4113,
#  'dressed': 1377,
#  'kid': 2463,
#  'history': 2121,
#  'nation': 2959,
#  'since': 3999,
#  'prince': 3397,
#  'william': 4841,
#  'preteen': 3379,
#  'public': 3452,
#  'appearances': 272,
#  'american': 216,
#  'there': 4398,
#  'wales': 4734,
#  'scotland': 3815,
#  'northern': 3020,
#  'ireland': 2352,
#  'meaning': 2774,
#  'culture': 1102,
#  'can': 697,
#  'handle': 2021,
#  'stereotyping': 4166,
#  'bad': 391,
#  'fire': 1728,
#  'looked': 2651,
#  'cool': 1019,
#  'though': 4415,
#  'notice': 3029,
#  'dvd': 1405,
#  'version': 4680,
#  'missing': 2851,
#  'scenes': 3806,
#  'between': 495,
#  'posting': 3343,
#  'frf': 1835,
#  'launch': 2538,
#  'prove': 3437,
#  'win': 4849,
#  'right': 3684,
#  'sit': 4010,
#  'green': 1973,
#  'team': 4344,
#  'another': 246,
#  'scene': 3805,
#  'failure': 1633,
#  'simulation': 3996,
#  'kevin': 2458,
#  'gets': 1908,
#  'joaquin': 2401,
#  'clam': 849,
#  'down': 1368,
#  'vhs': 4685,
#  'edition': 1432,
#  'abc': 69,
#  'one': 3085,
#  'might': 2824,
#  'stuff': 4220,
#  'watched': 4769,
#  'feels': 1678,
#  'edited': 1431,
#  'television': 4354,
#  'happens': 2033,
#  'when': 4816,
#  're': 3520,
#  'living': 2621,
#  'china': 819,
#  'local': 2627,
#  'video': 4691,
#  'store': 4178,
#  'language': 2519,
#  'titles': 4445,
#  'blessed': 531,
#  'work': 4893,
#  'appears': 274,
#  'romanian': 3720,
#  'cinema': 838,
#  'nevertheless': 2990,
#  'real': 3527,
#  'comedic': 914,
#  'potential': 3346,
#  'spoilers': 4112,
#  'technically': 4346,
#  'follow': 1770,
#  'would': 4904,
#  'fact': 1627,
#  'spoil': 4110,
#  'viewing': 4697,
#  'pleasure': 3291,
#  'ask': 318,
#  'casino': 739,
#  'beach': 435,
#  'archery': 283,
#  'flashback': 1743,
#  'mystery': 2940,
#  'many': 2730,
#  'conundrums': 1010,
#  'remain': 3595,
#  'exploited': 1605,
#  'desperate': 1236,
#  'comedians': 913,
#  'perhaps': 3210,
#  'stuck': 4212,
#  'bucharest': 632,
#  'let': 2576,
#  'me': 2772,
#  'wonder': 4883,
#  'aloud': 197,
#  'perfectly': 3206,
#  'looking': 2652,
#  'people': 3201,
#  'themselves': 4395,
#  'abuse': 81,
#  'sad': 3758,
#  'shining': 3943,
#  'over': 3129,
#  'quarter': 3473,
#  'century': 769,
#  'old': 3079,
#  'challenge': 775,
#  'get': 1907,
#  'freaked': 1823,
#  'jack': 2377,
#  'nicholson': 2997,
#  'descent': 1228,
#  'madness': 2696,
#  'rare': 3508,
#  'example': 1568,
#  'something': 4070,
#  'unique': 4605,
#  'no': 3006,
#  'able': 74,
#  'rip': 3691,
#  'instead': 2305,
#  'referenced': 3565,
#  'again': 156,
#  'pop': 3317,
#  'twins': 4551,
#  'elevator': 1455,
#  'redrum': 3561,
#  'crazy': 1065,
#  'nonsense': 3014,
#  'writing': 4912,
#  'seen': 3857,
#  'if': 2204,
#  'nothing': 3028,
#  'understand': 4579,
#  'allusions': 192,
#  'daily': 1121,
#  'simultaneously': 3997,
#  'scary': 3802,
#  'psychologically': 3447,
#  'intriguing': 2336,
#  'classic': 853,
#  'hitchcock': 2123,
#  'terror': 4374,
#  'modern': 2862,
#  'movies': 2911,
#  'usually': 4658,
#  'lack': 2507,
#  'great': 1968,
#  'script': 3825,
#  'cant': 706,
#  'believe': 475,
#  'actually': 116,
#  'yet': 4931,
#  'call': 679,
#  'batman': 425,
#  'going': 1941,
#  'far': 1654,
#  'say': 3787,
#  'btas': 631,
#  'plagiarism': 3273,
#  'them': 4391,
#  'use': 4650,
#  'name': 2946,
#  'piece': 3252,
#  'crap': 1061,
#  'whole': 4829,
#  'premise': 3366,
#  'show': 3966,
#  'defeat': 1180,
#  'someone': 4068,
#  'bigger': 501,
#  'weapon': 4785,
#  'help': 2086,
#  'about': 76,
#  'weapons': 4786,
#  'batarang': 422,
#  'grappling': 1963,
#  'hook': 2150,
#  'batmobile': 426,
#  'thats': 4386,
#  'doesn': 1349,
#  'come': 911,
#  'up': 4637,
#  'new': 2991,
#  'ingenious': 2278,
#  'tech': 4345,
#  'every': 1556,
#  'beat': 441,
#  'hell': 2083,
#  'batbot': 423,
#  'whatever': 4813,
#  'ruined': 3744,
#  'villains': 4703,
#  'mr': 2913,
#  'freeze': 1828,
#  'sympathetic': 4315,
#  'scientist': 3813,
#  'petty': 3231,
#  'fell': 1680,
#  'cryofreezing': 1098,
#  'thing': 4404,
#  'catwoman': 754,
#  '40': 47,
#  '50': 51,
#  'dumb': 1398,
#  'costume': 1033,
#  'penguin': 3200,
#  'ninja': 3001,
#  'ft': 1845,
#  'tall': 4333,
#  'top': 4463,
#  'hat': 2049,
#  'ventriloquist': 4678,
#  'called': 680,
#  'scarface': 3799,
#  'making': 2713,
#  'centerpiece': 766,
#  'him': 2113,
#  'giant': 1913,
#  'wtf': 4917,
#  'worst': 4902,
#  'changes': 783,
#  'joker': 2411,
#  'riddler': 3678,
#  'changed': 782,
#  'retro': 3656,
#  'teenage': 4349,
#  'freak': 1822,
#  'acrobat': 102,
#  'dreads': 1375,
#  'looks': 2653,
#  'bob': 551,
#  'marley': 2743,
#  'wannabe': 4745,
#  'completely': 946,
#  'utterly': 4660,
#  'moreso': 2889,
#  'did': 1270,
#  'wish': 4863,
#  'meet': 2788,
#  'creators': 1071,
#  'writers': 4910,
#  'animators': 240,
#  'whack': 4811,
#  'head': 2062,
#  'metal': 2811,
#  'baseball': 415,
#  'bat': 421,
#  'realise': 3528,
#  'us': 4648,
#  'army': 296,
#  'demoralised': 1208,
#  '1971': 26,
#  'unbelievable': 4570,
#  'supposed': 4278,
#  'training': 4497,
#  'camp': 690,
#  'ss': 4129,
#  'punishment': 3457,
#  'battalion': 427,
#  'sven': 4306,
#  'hassell': 2048,
#  'novel': 3033,
#  'writer': 4909,
#  'hater': 2052,
#  'psycho': 3446,
#  'sergeant': 3888,
#  'kept': 2455,
#  'beating': 443,
#  'belonged': 479,
#  'prison': 3403,
#  'cell': 761,
#  'useless': 4652,
#  'black': 517,
#  'sacked': 3757,
#  'men': 2795,
#  'overseas': 3133,
#  'receiving': 3542,
#  'units': 4608,
#  'surely': 4283,
#  'wondered': 4884,
#  'unusable': 4633,
#  'damaged': 1128,
#  'recruits': 3554,
#  'coming': 921,
#  'investigation': 2346,
#  'ensued': 1507,
#  'blew': 532,
#  'electrocution': 1451,
#  'farrell': 1657,
#  'alleged': 188,
#  'barrack': 409,
#  'room': 3726,
#  'lawyer': 2541,
#  'instructor': 2306,
#  'barrel': 410,
#  'issuing': 2368,
#  'illegal': 2210,
#  'order': 3106,
#  'torture': 4467,
#  'pows': 3353,
#  'contravention': 1006,
#  'geneva': 1892,
#  'convention': 1011,
#  'actual': 115,
#  'assault': 326,
#  'enlisted': 1503,
#  'man': 2717,
#  'conduct': 965,
#  'unbecoming': 4569,
#  'officer': 3069,
#  'intead': 2309,
#  'walks': 4740,
#  'away': 376,
#  'discipline': 1298,
#  'brakes': 590,
#  'madhouse': 2694,
#  'level': 2583,
#  'unwatchable': 4635,
#  'how': 2169,
#  'ended': 1481,
#  'went': 4807,
#  'bed': 452,
#  've': 4676,
#  'always': 204,
#  'thought': 4416,
#  'most': 2896,
#  'huge': 2176,
#  'box': 581,
#  'office': 3068,
#  'flops': 1758,
#  'recommend': 3550,
#  'remake': 3598,
#  'around': 297,
#  'world': 4898,
#  '80': 57,
#  'days': 1155,
#  'thunderbirds': 4430,
#  'doubt': 1365,
#  'those': 4414,
#  'familiar': 1644,
#  'based': 416,
#  'puppet': 3458,
#  'astronauts': 339,
#  'state': 4154,
#  'art': 306,
#  'rockets': 3708,
#  'spaceships': 4091,
#  'subs': 4234,
#  'rescue': 3632,
#  'various': 4674,
#  'disasters': 1295,
#  'falling': 1640,
#  'bridges': 604,
#  'stricken': 4198,
#  'planes': 3277,
#  'burning': 659,
#  'buildings': 643,
#  'etc': 1545,
#  'each': 1412,
#  'week': 4792,
#  'puppets': 3459,
#  'replaced': 3619,
#  'lifeless': 2590,
#  'teenagers': 4351,
#  'ineptly': 2270,
#  'staged': 4133,
#  'shamelessly': 3922,
#  'ripped': 3692,
#  'spy': 4125,
#  'kids': 2467,
#  'signs': 3986,
#  'imagination': 2217,
#  'wit': 4866,
#  'entertainment': 1511,
#  'alan': 179,
#  'tracey': 4484,
#  'left': 2557,
#  'rescuing': 3634,
#  'we': 4780,
#  'never': 2989,
#  'traceys': 4485,
#  'because': 449,
#  'dad': 1119,
#  'won': 4882,
#  'play': 3282,
#  'rocket': 3707,
#  'until': 4631,
#  'passes': 3178,
#  'exams': 1569,
#  'grounded': 1988,
#  'tropical': 4522,
#  'island': 2361,
#  'chance': 780,
#  'shine': 3942,
#  'comes': 917,
#  'rest': 3649,
#  'bunch': 652,
#  'identikit': 2200,
#  'bleach': 526,
#  'blondes': 539,
#  'gay': 1879,
#  'neo': 2986,
#  'nazi': 2967,
#  'band': 400,
#  'single': 4003,
#  'bit': 512,
#  'characterisation': 790,
#  'stranded': 4190,
#  'space': 4090,
#  'day': 1154,
#  'er': 1527,
#  'jungle': 2428,
#  'phone': 3237,
#  'firing': 1731,
#  'hose': 2160,
#  'inept': 2269,
#  'relief': 3590,
#  'dousing': 1367,
#  'gunk': 1999,
#  'points': 3301,
#  'mostly': 2897,
#  'focus': 1765,
#  'go': 1934,
#  'seychelles': 3911,
#  'nice': 2995,
#  'start': 4149,
#  'ben': 482,
#  'kingsley': 2479,
#  'career': 718,
#  'lowpoint': 2674,
#  'performance': 3208,
#  'aforementioned': 152,
#  'sidekicks': 3982,
#  'disgrace': 1312,
#  'children': 816,
#  'foundation': 1811,
#  'complete': 945,
#  'action': 107,
#  'effects': 1439,
#  '70m': 55,
#  'sci': 3811,
#  'fi': 1695,
#  'terrible': 4371,
#  'direction': 1285,
#  'odious': 3061,
#  'moralising': 2886,
#  'patronising': 3186,
#  'possible': 3338,
#  'way': 4776,
#  'forget': 1791,
#  'lessons': 2574,
#  'peg': 3197,
#  'sentiment': 3880,
#  'aimed': 172,
#  'straight': 4188,
#  'eights': 1445,
#  'constantly': 988,
#  'talking': 4331,
#  'intended': 2313,
#  'audience': 356,
#  'throwing': 4425,
#  'fifth': 1700,
#  'rate': 3509,
#  'jokes': 2412,
#  'routines': 3737,
#  'insult': 2307,
#  'recently': 3544,
#  'mastered': 2755,
#  'speech': 4100,
#  'replace': 3618,
#  'being': 470,
#  'sent': 3877,
#  'early': 1414,
#  'dinner': 1281,
#  'parents': 3163,
#  'favourite': 1667,
#  'biggest': 502,
#  'flop': 1757,
#  'cover': 1051,
#  'cost': 1031,
#  'prints': 3401,
#  'marketing': 2741,
#  'object': 3044,
#  'lesson': 2573,
#  'summer': 4258,
#  'ok': 3076,
#  'am': 205,
#  'zombie': 4944,
#  'fan': 1648,
#  'loved': 2667,
#  'romero': 3724,
#  'flicks': 1752,
#  'thoroughly': 4413,
#  'enjoyed': 1499,
#  'dawn': 1153,
#  'heard': 2067,
#  'critic': 1087,
#  'railing': 3495,
#  'optimistic': 3103,
#  'mean': 2773,
#  'critics': 1090,
#  'hated': 2051,
#  'resident': 3639,
#  'evil': 1563,
#  'particularly': 3172,
#  'fun': 1850,
#  'shoot': 3954,
#  'em': 1464,
#  'half': 2009,
#  'decent': 1169,
#  'pure': 3460,
#  'dialogue': 1266,
#  'assed': 327,
#  'game': 1865,
#  'inserted': 2294,
#  'mind': 2835,
#  'term': 4369,
#  'loosely': 2655,
#  'jurgen': 2431,
#  'prochnow': 3409,
#  'captain': 712,
#  'kirk': 2483,
#  'ugh': 4560,
#  'throws': 4427,
#  'originality': 3111,
#  'window': 4852,
#  'knows': 2497,
#  'god': 1937,
#  'awful': 379,
#  'best': 491,
#  'acts': 114,
#  'doing': 1352,
#  'shakespeare': 3919,
#  'very': 4683,
#  'badly': 392,
#  'add': 119,
#  'basically': 417,
#  'reason': 3535,
#  'monstrosity': 2881,
#  'buff': 639,
#  'flick': 1751,
#  'made': 2693,
#  'mst3k': 2916,
#  'home': 2140,
#  'friends': 1837,
#  'tons': 4460,
#  'unintentional': 4603,
#  'laughs': 2535,
#  'turkish': 4542,
#  'sweden': 4309,
#  'confess': 966,
#  'often': 3072,
#  'scandinavian': 3793,
#  'actors': 111,
#  'scandinavia': 3792,
#  'hollywood': 2137,
#  'last': 2525,
#  'polish': 3310,
#  'wedding': 4791,
#  'together': 4449,
#  'friend': 1836,
#  'mine': 2836,
#  'both': 576,
#  'said': 3761,
#  'unfortunately': 4596,
#  'wrong': 4914,
#  'angels': 229,
#  'worse': 4900,
#  'none': 3013,
#  'act': 104,
#  'absolutely': 80,
#  'star': 4146,
#  'helen': 2081,
#  'bergstrom': 485,
#  'silly': 3989,
#  'nobody': 3008,
#  'mess': 2808,
#  'lots': 2662,
#  'acting': 106,
#  ...}

# %% [markdown]
# Next, we need to call "transform()" to get a term-document matrix. Try it out and find out what it produces:

# %%
term_doc_mat = vectorizer.transform(input_text).T  # transpose so that rows are terms
print(term_doc_mat)
print(term_doc_mat.shape)
# Out:
# <Compressed Sparse Column sparse matrix of dtype 'int64'
# 	with 14775 stored elements and shape (4945, 100)>
#   Coords	Values
#   (187, 0)	1
#   (193, 0)	1
#   (200, 0)	1
#   (226, 0)	5
#   (247, 0)	1
#   (256, 0)	1
#   (340, 0)	3
#   (420, 0)	1
#   (494, 0)	1
#   (563, 0)	7
#   (614, 0)	1
#   (665, 0)	1
#   (717, 0)	1
#   (727, 0)	1
#   (744, 0)	1
#   (781, 0)	1
#   (788, 0)	1
#   (791, 0)	1
#   (890, 0)	1
#   (908, 0)	1
#   (928, 0)	1
#   (1271, 0)	1
#   (1294, 0)	1
#   (1334, 0)	1
#   (1348, 0)	1
#   :	:
#   (4111, 99)	1
#   (4225, 99)	1
#   (4231, 99)	1
#   (4253, 99)	1
#   (4381, 99)	1
#   (4385, 99)	4
#   (4387, 99)	12
#   (4393, 99)	1
#   (4396, 99)	1
#   (4398, 99)	1
#   (4410, 99)	2
#   (4446, 99)	5
#   (4467, 99)	2
#   (4553, 99)	1
#   (4580, 99)	1
#   (4637, 99)	1
#   (4675, 99)	1
#   (4695, 99)	2
#   (4821, 99)	1
#   (4869, 99)	1
#   (4881, 99)	1
#   (4900, 99)	1
#   (4904, 99)	1
#   (4934, 99)	1
#   (4938, 99)	1
# (4945, 100)

# %% [markdown]
# **TO-DO 8:** Use the term-document matrix above to write a function that returns a term vector. Get the term vector for the word 'happy'.

# %%
# WRITE YOUR ANSWER HERE

def get_term_vector(vectorizer, term_document_matrix, term):
    term_index = vectorizer.vocabulary_[term]
    return term_document_matrix[term_index]

term_vec = get_term_vector(vectorizer, term_doc_mat, "happy")
print(term_vec)
# Out:
# <Compressed Sparse Column sparse matrix of dtype 'int64'
# 	with 4 stored elements and shape (1, 100)>
#   Coords	Values
#   (0, 2)	1
#   (0, 64)	1
#   (0, 79)	2
#   (0, 83)	1

# %% [markdown]
# **TO-DO 9:** What do the values in the vector mean? This representation is known as a 'bag of words' because it ignores the word order and document structure. Can you think of any disadvantages of representing documents as bags of words?

# %% [markdown]
# ANSWER = these are the number of times the chosen word (or other token type, such as punctuation mark or number) occured in each document in the dataset.

# %% [markdown]
# # 6. Comparing Vectors with Cosine Similarity
#
# Vectors representations allow us to compare documents or terms by computing their similarity. This is useful for tasks such as clustering documents into topics, or finding documents that are similar to a 'query' document.
# In order to compute similarity or distance, we need to represent documents as numerical vectors.
#
# The most common way to compare vectors is to compute the cosine of the angles between them. This measures how much the vectors point in the same direction. It ignores their magnitude, which means that shorter documents with lower word counts can be directly compared to long documents with more words.
#
# Let's take a term from the IMDB dataset as a 'query' and compare it to two others using cosine similarity:

# %%
# get our first document
query_vec = get_term_vector(vectorizer, term_doc_mat, 'happy')
print(query_vec)

# get the second term
term2_vec = get_term_vector(vectorizer, term_doc_mat, 'sad')
print(term2_vec)

# get a third term
term3_vec = get_term_vector(vectorizer, term_doc_mat, 'enjoy')
print(term3_vec)
# Out:
# <Compressed Sparse Column sparse matrix of dtype 'int64'
# 	with 4 stored elements and shape (1, 100)>
#   Coords	Values
#   (0, 2)	1
#   (0, 64)	1
#   (0, 79)	2
#   (0, 83)	1
# <Compressed Sparse Column sparse matrix of dtype 'int64'
# 	with 4 stored elements and shape (1, 100)>
#   Coords	Values
#   (0, 5)	1
#   (0, 21)	1
#   (0, 23)	1
#   (0, 80)	1
# <Compressed Sparse Column sparse matrix of dtype 'int64'
# 	with 4 stored elements and shape (1, 100)>
#   Coords	Values
#   (0, 13)	1
#   (0, 22)	1
#   (0, 92)	1
#   (0, 97)	1

# %% [markdown]
# Cosine similarity is defined as:
#
# $$similarity<v_1, v_2> = \frac{v_1 \cdot v_2}{|| v_1 || \cdot || v_2 ||}$$
#
# **TO-DO 9:** Complete the function below to computes cosine similarity between two vectors. Hint: use Numpy's dot function for the dot product.

# %%
query_vec
# Out:
# <Compressed Sparse Column sparse matrix of dtype 'int64'
# 	with 4 stored elements and shape (1, 100)>

# %%
def cossim(vec1, vec2):
    ### WRITE YOUR OWN CODE HERE
    cosine_similarity = np.dot(vec1, vec2) / np.dot((np.linalg.norm(vec1), np.linalg.norm(vec2)))
    return cosine_similarity
    #######

# %% [markdown]
# **TO-DO 10:** Which term do you expect to have higher similarity to the query? Run the code below to use your cosine similarity function, and see if the results meet your expectations.
#
# ANSWER: -- The 'enjoy' should be more similar to 'happy' than 'sad'.

# %%
cos_sim1 = cossim(query_vec, term2_vec)
print(f'The cosine similarity between the query and term2 is: {cos_sim1}')

cos_sim2 = cossim(query_vec, term3_vec)
print(f'The cosine similarity between the query and term3 is: {cos_sim2}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 cos_sim1 = cossim(query_vec, term2_vec)
#       2 print(f'The cosine similarity between the query and term2 is: {cos_sim1}')
#       4 cos_sim2 = cossim(query_vec, term3_vec)
#
# Cell In[67], line 3, in cossim(vec1, vec2)
#       1 def cossim(vec1, vec2):
#       2     ### WRITE YOUR OWN CODE HERE
# ----> 3     cosine_similarity = np.dot(vec1, vec2) / np.dot((np.linalg.norm(vec1), np.linalg.norm(vec2)))
#       4     return cosine_similarity
#
# File c:\Users\ksstu\.conda\envs\text_analytics\Lib\site-packages\scipy\sparse\_matrix.py:45, in spmatrix.__mul__(self, other)
#      44 def __mul__(self, other):
# ---> 45     return self._matmul_dispatch(other)
#
# File c:\Users\ksstu\.conda\envs\text_analytics\Lib\site-packages\scipy\sparse\_base.py:824, in _spbase._matmul_dispatch(self, other)
#     822 if issparse(other):
#     823     if N != other.shape[0]:
# --> 824         raise ValueError(
#     825             f"{err_prefix} (n,k={N}),(k={other.shape[0]},m)->(n,m)"
#     826         )
#     827     return self._matmul_sparse(other)
#     829 # If it's a list or whatever, treat it like an array
#
# ValueError: matmul: dimension mismatch with signature (n,k=100),(k=1,m)->(n,m)

# %% [markdown]
# # 7. Bags of N-grams
#
# Our representations above were purely bag-of-words representations: they ignored word order and simply counted single tokens, or 'unigrams'. However, word order is important for understanding the meaning of a piece of text. What if we expand our bags of words to also count other _features_ that help us account for word order? Features are any attributes of the text that we can measure; a simple improvement is to count pairs of consecutive tokens, or _bigrams_, to capture phrases as well as individual words.

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(1,2))  # include bigrams as well as unigrams
bigram_vectorizer.fit(input_text)  
bigram_vectorizer.vocabulary_  # show the vocabulary of the bigram vectorizer, which includes both unigrams and bigrams
# Out:
# {'didn': 5397,
#  'care': 3793,
#  'for': 7226,
#  'the': 19002,
#  'movie': 12769,
#  'book': 2984,
#  'was': 21889,
#  'better': 2760,
#  'does': 5662,
#  'anyone': 1512,
#  'know': 11037,
#  'where': 22435,
#  'it': 10400,
#  'filmed': 6973,
#  'this': 20152,
#  'my': 13014,
#  'first': 7072,
#  'visit': 21742,
#  'to': 20496,
#  'your': 23344,
#  'site': 17539,
#  'just': 10804,
#  'found': 7397,
#  'answer': 1456,
#  'question': 15655,
#  'so': 17637,
#  'now': 13582,
#  'look': 11714,
#  'like': 11442,
#  'dummy': 5868,
#  'but': 3434,
#  'think': 20109,
#  'll': 11617,
#  'still': 18133,
#  'submit': 18374,
#  'comments': 4444,
#  'and': 945,
#  'yes': 23226,
#  'british': 3286,
#  'columbia': 4366,
#  'is': 10074,
#  'lovely': 11824,
#  'or': 14344,
#  'why': 22635,
#  'they': 20014,
#  'took': 20843,
#  'from': 7508,
#  'its': 10593,
#  'south': 17905,
#  'carolina': 3820,
#  'coastal': 4321,
#  'setting': 17107,
#  'stands': 18044,
#  'place': 15052,
#  'essential': 6290,
#  'fabric': 6594,
#  'of': 13683,
#  'change': 3975,
#  'part': 14703,
#  'disappointment': 5507,
#  'with': 22784,
#  'oh': 14034,
#  'read': 15804,
#  'need': 13198,
#  'write': 23130,
#  'at': 1997,
#  'least': 11255,
#  'ten': 18739,
#  'lines': 11522,
#  'here': 8869,
#  'other': 14458,
#  'main': 11962,
#  'issue': 10390,
#  'film': 6884,
#  'kim': 10985,
#  'bassinger': 2299,
#  'too': 20823,
#  'vapid': 21552,
#  'not': 13429,
#  'all': 609,
#  'what': 22336,
#  'pictured': 14999,
#  'well': 22241,
#  'good': 7972,
#  'character': 3999,
#  'in': 9579,
#  'much': 12917,
#  'more': 12655,
#  'empathetic': 6086,
#  'also': 726,
#  'evoked': 6440,
#  'rustic': 16509,
#  'almost': 687,
#  'primitive': 15437,
#  'images': 9512,
#  'monastery': 12601,
#  'while': 22492,
#  'castle': 3878,
#  'visually': 21749,
#  'impressive': 9567,
#  'distorted': 5601,
#  'feel': 6780,
#  'story': 18195,
#  'seemed': 16927,
#  'odds': 13679,
#  'characters': 4024,
#  'didn care': 5398,
#  'care for': 3797,
#  'for the': 7311,
#  'the movie': 19476,
#  'movie the': 12846,
#  'the book': 19092,
#  'book was': 2995,
#  'was better': 21906,
#  'better does': 2768,
#  'does anyone': 5663,
#  'anyone know': 1514,
#  'know where': 11058,
#  'where it': 22443,
#  'it was': 10568,
#  'was filmed': 21932,
#  'filmed this': 6977,
#  'this was': 20269,
#  'was my': 21973,
#  'my first': 13032,
#  'first visit': 7097,
#  'visit to': 21744,
#  'to your': 20768,
#  'your site': 23362,
#  'site just': 17540,
#  'just found': 10822,
#  'found the': 7404,
#  'the answer': 19050,
#  'answer to': 1459,
#  'to my': 20659,
#  'my question': 13055,
#  'question so': 15656,
#  'so now': 17675,
#  'now look': 13595,
#  'look like': 11724,
#  'like dummy': 11457,
#  'dummy but': 5869,
#  'but think': 3509,
#  'think ll': 20122,
#  'll still': 11627,
#  'still submit': 18155,
#  'submit my': 18375,
#  'my comments': 13023,
#  'comments and': 4446,
#  'and yes': 1377,
#  'yes british': 23227,
#  'british columbia': 3289,
#  'columbia is': 4367,
#  'is lovely': 10208,
#  'lovely or': 11825,
#  'or why': 14410,
#  'why they': 22650,
#  'they took': 20067,
#  'took it': 20844,
#  'it from': 10460,
#  'from its': 7538,
#  'its south': 10624,
#  'south carolina': 17906,
#  'carolina coastal': 3821,
#  'coastal setting': 4322,
#  'setting this': 17108,
#  'this question': 20237,
#  'question stands': 15657,
#  'stands the': 18046,
#  'the place': 19542,
#  'place was': 15056,
#  'was essential': 21927,
#  'essential to': 6291,
#  'to the': 20741,
#  'the fabric': 19253,
#  'fabric of': 6595,
#  'of the': 13943,
#  'book and': 2985,
#  'and its': 1127,
#  'its change': 10600,
#  'change was': 3979,
#  'was part': 21983,
#  'part of': 14707,
#  'of my': 13864,
#  'my disappointment': 13026,
#  'disappointment with': 5509,
#  'with the': 22876,
#  'movie oh': 12828,
#  'oh just': 14037,
#  'just read': 10839,
#  'read where': 15816,
#  'where need': 22445,
#  'need to': 13202,
#  'to write': 20763,
#  'write at': 23131,
#  'at least': 2024,
#  'least ten': 11265,
#  'ten lines': 18740,
#  'lines here': 11527,
#  'here my': 8891,
#  'my other': 13049,
#  'other main': 14479,
#  'main issue': 11970,
#  'issue with': 10395,
#  'the film': 19273,
#  'film kim': 6933,
#  'kim bassinger': 10986,
#  'bassinger was': 2300,
#  'was too': 22018,
#  'too vapid': 20842,
#  'vapid and': 21553,
#  'and not': 1189,
#  'not at': 13439,
#  'at all': 2001,
#  'all what': 672,
#  'what pictured': 22364,
#  'pictured from': 15000,
#  'from the': 7558,
#  'book know': 2991,
#  'know the': 11054,
#  'was the': 22011,
#  'and the': 1304,
#  'movie well': 12861,
#  'well not': 22260,
#  'not so': 13519,
#  'so good': 17661,
#  'good found': 7986,
#  'the character': 19126,
#  'character in': 4007,
#  'in the': 9744,
#  'book much': 2992,
#  'much more': 12933,
#  'more empathetic': 12665,
#  'empathetic also': 6087,
#  'also the': 751,
#  'book evoked': 2988,
#  'evoked rustic': 6442,
#  'rustic almost': 16510,
#  'almost primitive': 699,
#  'primitive images': 15438,
#  'images of': 9514,
#  'the monastery': 19468,
#  'monastery while': 12607,
#  'while the': 22510,
#  'the castle': 19124,
#  'castle in': 3879,
#  'film was': 6965,
#  'was much': 21971,
#  'more visually': 12685,
#  'visually impressive': 21750,
#  'impressive it': 9571,
#  'it distorted': 10446,
#  'distorted the': 5602,
#  'the feel': 19267,
#  'feel of': 6782,
#  'the story': 19690,
#  'story and': 18197,
#  'and seemed': 1253,
#  'seemed at': 16928,
#  'at odds': 2026,
#  'odds with': 13680,
#  'the characters': 19127,
#  'vampyres': 21541,
#  'br': 3078,
#  'aspect': 1957,
#  'ratio': 15761,
#  '85': 148,
#  'sound': 17882,
#  'format': 7371,
#  'mono': 12633,
#  'motorist': 12753,
#  'murray': 12965,
#  'brown': 3328,
#  'lured': 11872,
#  'an': 857,
#  'isolated': 10382,
#  'country': 4766,
#  'house': 9286,
#  'inhabited': 9863,
#  'by': 3536,
#  'two': 21130,
#  'beautiful': 2465,
#  'young': 23327,
#  'women': 22940,
#  'marianne': 12152,
#  'morris': 12700,
#  'anulka': 1473,
#  'becomes': 2531,
#  'enmeshed': 6198,
#  'their': 19824,
#  'free': 7441,
#  'spirited': 17961,
#  'sexual': 17138,
#  'lifestyle': 11421,
#  'his': 9011,
#  'hosts': 9267,
#  'turn': 21093,
#  'out': 14526,
#  'be': 2332,
#  'vampires': 21539,
#  'frenzied': 7465,
#  'lust': 11876,
#  'human': 9369,
#  'blood': 2927,
#  'taking': 18634,
#  'cue': 4923,
#  'lesbian': 11327,
#  'vampire': 21535,
#  'cycle': 4966,
#  'initiated': 9871,
#  'maverick': 12229,
#  'director': 5475,
#  'jean': 10674,
#  'rollin': 16402,
#  'france': 7416,
#  'consolidated': 4596,
#  'success': 18396,
#  'hammer': 8282,
#  'carmilla': 3815,
#  'series': 17053,
#  'uk': 21181,
#  'jose': 10763,
#  'ramon': 15718,
#  'larraz': 11151,
#  'daring': 5019,
#  'shocker': 17301,
#  'pushed': 15610,
#  'concept': 4520,
#  'adult': 434,
#  'horror': 9244,
#  'further': 7633,
#  'than': 18786,
#  'censors': 3930,
#  'were': 22284,
#  'prepared': 15363,
#  'tolerate': 20802,
#  '1974': 68,
#  'cut': 4954,
#  'three': 20338,
#  'minutes': 12510,
#  'on': 14090,
#  'original': 14430,
#  'release': 16038,
#  'isn': 10368,
#  'difficult': 5448,
#  'see': 16872,
#  'using': 21490,
#  'gothic': 8043,
#  'theme': 19917,
#  'as': 1800,
#  'pretext': 15401,
#  'nudity': 13618,
#  'sex': 17128,
#  'bloodshed': 2933,
#  'short': 17316,
#  'running': 16493,
#  'time': 20411,
#  'will': 22675,
#  'allow': 676,
#  'who': 22528,
#  'wrote': 23176,
#  'screenplay': 16789,
#  'under': 21206,
#  'pseudonym': 15557,
#  'daubeney': 5039,
#  'uses': 21483,
#  'these': 19991,
#  'commercial': 4454,
#  'elements': 6032,
#  'mere': 12380,
#  'backdrop': 2183,
#  'languid': 11139,
#  'meditation': 12327,
#  'life': 11393,
#  'death': 5108,
#  'impulses': 9575,
#  'otherwise': 14503,
#  'which': 22458,
#  'affirm': 463,
#  'condition': 4540,
#  'shot': 17331,
#  'location': 11653,
#  'picturesque': 15003,
#  'during': 5873,
#  'autumn': 2108,
#  '1973': 66,
#  'harry': 8365,
#  'waxman': 22110,
#  'haunting': 8447,
#  'cinematography': 4186,
#  'conjures': 4573,
#  'atmosphere': 2043,
#  'grim': 8129,
#  'foreboding': 7337,
#  'desolate': 5281,
#  'countryside': 4771,
#  'bleak': 2902,
#  'equal': 6254,
#  'measure': 12307,
#  'seems': 16933,
#  'foreshadow': 7343,
#  'whirlwind': 22522,
#  'impending': 9538,
#  'pulled': 15583,
#  'similar': 17461,
#  'trick': 20997,
#  'earlier': 5914,
#  'same': 16553,
#  'year': 23196,
#  'symptoms': 18601,
#  'low': 11840,
#  'key': 10930,
#  'thriller': 20346,
#  'erupts': 6273,
#  'into': 9997,
#  'frenzy': 7467,
#  'violence': 21721,
#  'final': 7016,
#  'reel': 15982,
#  'however': 9331,
#  'despite': 5289,
#  'pretensions': 15397,
#  'wafer': 21791,
#  'thin': 20076,
#  'plot': 15131,
#  'rough': 16450,
#  'hewn': 8927,
#  'production': 15491,
#  'values': 21532,
#  'divide': 5616,
#  'audiences': 2089,
#  'outset': 14575,
#  'female': 6806,
#  'protagonists': 15523,
#  'are': 1619,
#  'charismatic': 4054,
#  'appealing': 1571,
#  'could': 4722,
#  'wished': 22771,
#  'male': 12054,
#  'lead': 11225,
#  'past': 14748,
#  'prime': 15435,
#  'filming': 6979,
#  'woefully': 22915,
#  'miscast': 12525,
#  'role': 16379,
#  'that': 18825,
#  'should': 17340,
#  'have': 8449,
#  'gone': 7961,
#  'some': 17752,
#  'twentysomething': 21122,
#  'stud': 18310,
#  'must': 12999,
#  'item': 10589,
#  'cult': 4925,
#  'fans': 6692,
#  'amusing': 855,
#  'curio': 4934,
#  'everyone': 6409,
#  'else': 6050,
#  'acquired': 294,
#  'taste': 18671,
#  'watch': 22054,
#  'silent': 17452,
#  'era': 6262,
#  'superstar': 18485,
#  'bessie': 2732,
#  'love': 11792,
#  'brief': 3261,
#  'cameo': 3659,
#  'end': 6099,
#  'vampyres br': 21542,
#  'br br': 3095,
#  'br aspect': 3090,
#  'aspect ratio': 1958,
#  'ratio 85': 15762,
#  '85 br': 149,
#  'br sound': 3181,
#  'sound format': 17884,
#  'format mono': 7372,
#  'mono br': 12634,
#  'br motorist': 3147,
#  'motorist murray': 12754,
#  'murray brown': 12966,
#  'brown is': 3330,
#  'is lured': 10209,
#  'lured to': 11873,
#  'to an': 20513,
#  'an isolated': 913,
#  'isolated country': 10384,
#  'country house': 4768,
#  'house inhabited': 9290,
#  'inhabited by': 9864,
#  'by two': 3603,
#  'two beautiful': 21133,
#  'beautiful young': 2480,
#  'young women': 23341,
#  'women marianne': 22950,
#  'marianne morris': 12153,
#  'morris and': 12701,
#  'and anulka': 968,
#  'anulka and': 1474,
#  'and becomes': 987,
#  'becomes enmeshed': 2536,
#  'enmeshed in': 6199,
#  'in their': 9746,
#  'their free': 19841,
#  'free spirited': 7444,
#  'spirited sexual': 17962,
#  'sexual lifestyle': 17142,
#  'lifestyle but': 11423,
#  'but his': 3465,
#  'his hosts': 9066,
#  'hosts turn': 9268,
#  'turn out': 21098,
#  'out to': 14562,
#  'to be': 20525,
#  'be vampires': 2431,
#  'vampires with': 21540,
#  'with frenzied': 22813,
#  'frenzied lust': 7466,
#  'lust for': 11877,
#  'for human': 7274,
#  'human blood': 9371,
#  'blood br': 2929,
#  'br taking': 3184,
#  'taking its': 18635,
#  'its cue': 10604,
#  'cue from': 4924,
#  'the lesbian': 19417,
#  'lesbian vampire': 11328,
#  'vampire cycle': 21536,
#  'cycle initiated': 4967,
#  'initiated by': 9872,
#  'by maverick': 3578,
#  'maverick director': 12230,
#  'director jean': 5482,
#  'jean rollin': 10676,
#  'rollin in': 16403,
#  'in france': 9653,
#  'france and': 7417,
#  'and consolidated': 1015,
#  'consolidated by': 4597,
#  'by the': 3598,
#  'the success': 19702,
#  'success of': 18397,
#  'of hammer': 13798,
#  'hammer carmilla': 8283,
#  'carmilla series': 3816,
#  'series in': 17060,
#  'the uk': 19751,
#  'uk jose': 21185,
#  'jose ramon': 10764,
#  'ramon larraz': 15719,
#  'larraz daring': 11152,
#  'daring shocker': 5020,
#  'shocker vampyres': 17302,
#  'vampyres pushed': 21544,
#  'pushed the': 15611,
#  'the concept': 19154,
#  'concept of': 4521,
#  'of adult': 13692,
#  'adult horror': 436,
#  'horror much': 9252,
#  'much further': 12925,
#  'further than': 7634,
#  'than british': 18794,
#  'british censors': 3287,
#  'censors were': 3933,
#  'were prepared': 22315,
#  'prepared to': 15365,
#  'to tolerate': 20748,
#  'tolerate in': 20803,
#  'in 1974': 9583,
#  '1974 and': 69,
#  'and his': 1108,
#  'his film': 9053,
#  'was cut': 21921,
#  'cut by': 4955,
#  'by almost': 3540,
#  'almost three': 701,
#  'three minutes': 20340,
#  'minutes on': 12516,
#  'on its': 14125,
#  'its original': 10620,
#  'original british': 14433,
#  'british release': 3293,
#  'release it': 16041,
#  'it isn': 10482,
#  'isn difficult': 10371,
#  'difficult to': 5449,
#  'to see': 20703,
#  'see why': 16906,
#  'why using': 22652,
#  'using its': 21492,
#  'its gothic': 10609,
#  'gothic theme': 8045,
#  'theme as': 19918,
#  'as the': 1904,
#  'the pretext': 19564,
#  'pretext for': 15402,
#  'for as': 7235,
#  'as much': 1869,
#  'much nudity': 12934,
#  'nudity sex': 13619,
#  'sex and': 17129,
#  'and bloodshed': 990,
#  'bloodshed as': 2934,
#  'film short': 6953,
#  'short running': 17320,
#  'running time': 16500,
#  'time will': 20454,
#  'will allow': 22676,
#  'allow larraz': 678,
#  'larraz who': 11154,
#  'who wrote': 22605,
#  'wrote the': 23179,
#  'the screenplay': 19633,
#  'screenplay under': 16793,
#  'under the': 21211,
#  'the pseudonym': 19577,
#  'pseudonym daubeney': 15558,
#  'daubeney uses': 5040,
#  'uses these': 21489,
#  'these commercial': 19995,
#  'commercial elements': 4455,
#  'elements as': 6033,
#  'as mere': 1862,
#  'mere backdrop': 12381,
#  'backdrop to': 2184,
#  'to languid': 20633,
#  'languid meditation': 11140,
#  'meditation on': 12328,
#  'on life': 14128,
#  'life death': 11400,
#  'death and': 5109,
#  'the impulses': 19358,
#  'impulses sexual': 9576,
#  'sexual and': 17139,
#  'and otherwise': 1200,
#  'otherwise which': 14509,
#  'which affirm': 22461,
#  'affirm the': 464,
#  'the human': 19347,
#  'human condition': 9372,
#  'condition br': 4541,
#  'br shot': 3175,
#  'shot on': 17333,
#  'on location': 14130,
#  'location at': 11654,
#  'at picturesque': 2030,
#  'picturesque country': 15004,
#  'house during': 9288,
#  'during the': 5877,
#  'the autumn': 19061,
#  'autumn of': 2109,
#  'of 1973': 13688,
#  '1973 harry': 67,
#  'harry waxman': 8369,
#  'waxman haunting': 22111,
#  'haunting cinematography': 8448,
#  'cinematography conjures': 4188,
#  'conjures an': 4574,
#  'an atmosphere': 883,
#  'atmosphere of': 2046,
#  'of grim': 13797,
#  'grim foreboding': 8130,
#  'foreboding in': 7338,
#  'in which': 9764,
#  'which the': 22487,
#  'the desolate': 19203,
#  'desolate countryside': 5282,
#  'countryside bleak': 4772,
#  'bleak and': 2903,
#  'and beautiful': 986,
#  'beautiful in': 2472,
#  'in equal': 9640,
#  'equal measure': 6255,
#  'measure seems': 12309,
#  'seems to': 16940,
#  'to foreshadow': 20593,
#  'foreshadow whirlwind': 7344,
#  'whirlwind of': 22523,
#  'of impending': 13816,
#  'impending horror': 9539,
#  'horror larraz': 9249,
#  'larraz pulled': 11153,
#  'pulled similar': 15584,
#  'similar trick': 17462,
#  'trick earlier': 20998,
#  'earlier the': 5916,
#  'the same': 19623,
#  'same year': 16568,
#  'year with': 23201,
#  'with symptoms': 22874,
#  'symptoms low': 18602,
#  'low key': 11843,
#  'key thriller': 10932,
#  'thriller which': 20354,
#  'which erupts': 22469,
#  'erupts into': 6274,
#  'into frenzy': 10003,
#  'frenzy of': 7468,
#  'of violence': 13970,
#  'violence during': 21723,
#  'the final': 19279,
#  'final reel': 7018,
#  'reel however': 15983,
#  'however despite': 9335,
#  'despite its': 5291,
#  'its pretensions': 10622,
#  'pretensions vampyres': 15398,
#  'vampyres wafer': 21545,
#  'wafer thin': 21792,
#  'thin plot': 20078,
#  'plot and': 15134,
#  'and rough': 1242,
#  'rough hewn': 16451,
#  'hewn production': 8928,
#  'production values': 15494,
#  'values will': 21534,
#  'will divide': 22686,
#  'divide audiences': 5617,
#  'audiences from': 2091,
#  'the outset': 19518,
#  'outset and': 14576,
#  'and while': 1361,
#  'the two': 19750,
#  'two female': 21138,
#  'female protagonists': 6809,
#  'protagonists are': 15524,
#  'are as': 1626,
#  'as charismatic': 1815,
#  'charismatic and': 4055,
#  'and appealing': 970,
#  'appealing as': 1572,
#  'as could': 1820,
#  'could be': 4726,
#  'be wished': 2435,
#  'wished the': 22773,
#  'the male': 19442,
#  'male lead': 12055,
#  'lead brown': 11226,
#  'brown past': 3331,
#  'past his': 14751,
#  'his prime': 9092,
#  'prime at': 15436,
#  'at the': 2037,
#  'the time': 19729,
#  'time of': 20435,
#  'of filming': 13782,
#  'filming is': 6981,
#  'is woefully': 10352,
#  'woefully miscast': 22916,
#  'miscast in': 12526,
#  'in role': 9726,
#  'role that': 16387,
#  'that should': 18954,
#  'should have': 17346,
#  'have gone': 8483,
#  'gone to': 7968,
#  'to some': 20720,
#  'some beautiful': 17756,
#  'beautiful twentysomething': 2478,
#  'twentysomething stud': 21123,
#  'stud must': 18311,
#  'must see': 13006,
#  'see item': 16888,
#  'item for': 10590,
#  'for cult': 7250,
#  'cult movie': 4927,
#  'movie fans': 12794,
#  'fans an': 6693,
#  'an amusing': 872,
#  'amusing curio': 856,
#  'curio for': 4935,
#  'for everyone': 7255,
#  'everyone else': 6411,
#  'else vampyres': 6061,
#  'vampyres is': 21543,
#  'is an': 10090,
#  'an acquired': 859,
#  'acquired taste': 295,
#  'taste watch': 18676,
#  'watch out': 22066,
#  'out for': 14535,
#  'for silent': 7304,
#  'silent era': 17453,
#  'era superstar': 6264,
#  'superstar bessie': 18486,
#  'bessie love': 2733,
#  'love in': 11803,
#  'in brief': 9610,
#  'brief cameo': 3262,
#  'cameo at': 3660,
#  'the end': 19233,
#  'end of': 6107,
#  'interesting': 9963,
#  'naive': 13092,
#  'park': 14699,
#  'ranger': 15728,
#  'colin': 4337,
#  'firth': 7098,
#  'marries': 12175,
#  'pretty': 15403,
#  'mysterious': 13074,
#  'woman': 22921,
#  'lisa': 11538,
#  'zane': 23372,
#  'he': 8559,
#  'only': 14260,
#  'known': 11068,
#  'seem': 16924,
#  'happy': 8339,
#  'then': 19930,
#  'she': 17202,
#  'disappears': 5500,
#  'without': 22889,
#  'warning': 21873,
#  'searches': 16832,
#  'her': 8784,
#  'after': 480,
#  'few': 6832,
#  'dead': 5087,
#  'ends': 6127,
#  'stumbles': 18338,
#  'upon': 21419,
#  'abused': 251,
#  'childhood': 4109,
#  'sleazy': 17577,
#  'recent': 15931,
#  'may': 12231,
#  'include': 9783,
#  'criminal': 4883,
#  'activity': 340,
#  'filmmakers': 6988,
#  'do': 5620,
#  'beginning': 2615,
#  'suspenseful': 18561,
#  'sounds': 17893,
#  'watchable': 22074,
#  'ceases': 3914,
#  'even': 6322,
#  'make': 11980,
#  'sense': 17006,
#  'ending': 6124,
#  'lame': 11116,
#  'dull': 5854,
#  'devoid': 5342,
#  'any': 1477,
#  'excitement': 6474,
#  'intelligence': 9935,
#  'you': 23252,
#  'screenwriters': 16797,
#  'got': 8024,
#  'bored': 3004,
#  'trying': 21070,
#  'sorry': 17871,
#  'waste': 22043,
#  'idea': 9434,
#  'it interesting': 10479,
#  'interesting at': 9966,
#  'at first': 2013,
#  'first naive': 7084,
#  'naive park': 13095,
#  'park ranger': 14700,
#  'ranger colin': 15729,
#  'colin firth': 4338,
#  'firth marries': 7099,
#  'marries pretty': 12176,
#  'pretty mysterious': 15415,
#  'mysterious woman': 13077,
#  'woman lisa': 22926,
#  'lisa zane': 11542,
#  'zane he': 23373,
#  'he only': 8628,
#  'only known': 14285,
#  'known for': 11070,
#  'for short': 7303,
#  'short time': 17324,
#  'time they': 20443,
#  'they seem': 20057,
#  'seem to': 16926,
#  'be happy': 2376,
#  'happy then': 8343,
#  'then she': 19943,
#  'she disappears': 17210,
#  'disappears without': 5501,
#  'without warning': 22903,
#  'warning he': 21875,
#  'he searches': 8646,
#  'searches for': 16833,
#  'for her': 7269,
#  'her and': 8788,
#  'and after': 954,
#  'after few': 487,
#  'few dead': 6836,
#  'dead ends': 5091,
#  'ends stumbles': 6130,
#  'stumbles upon': 18339,
#  'upon some': 21420,
#  'some of': 17777,
#  'of her': 13802,
#  'her abused': 8785,
#  'abused childhood': 253,
#  'childhood and': 4110,
#  'and sleazy': 1268,
#  'sleazy recent': 17578,
#  'recent past': 15932,
#  'past which': 14755,
#  'which may': 22479,
#  'may include': 12236,
#  'include criminal': 9785,
#  'criminal activity': 4884,
#  'activity and': 341,
#  'and then': 1306,
#  'then it': 19939,
#  'it seems': 10533,
#  'seems the': 16939,
#  'the filmmakers': 19276,
#  'filmmakers didn': 6989,
#  'didn know': 5403,
#  'know what': 11057,
#  'what to': 22374,
#  'to do': 20569,
#  'do with': 5645,
#  'story the': 18220,
#  'the beginning': 19078,
#  'beginning while': 2620,
#  'while not': 22505,
#  'not as': 13438,
#  'as suspenseful': 1899,
#  'suspenseful as': 18562,
#  'as it': 1851,
#  'it sounds': 10541,
#  'sounds is': 17896,
#  'is at': 10097,
#  'least watchable': 11266,
#  'watchable then': 22076,
#  'it ceases': 10431,
#  'ceases to': 3915,
#  'be interesting': 2386,
#  'interesting or': 9972,
#  'or even': 14368,
#  'even make': 6345,
#  'make much': 11994,
#  'much sense': 12937,
#  'sense and': 17007,
#  'the ending': 19234,
#  'ending is': 6125,
#  'is so': 10293,
#  'so lame': 17671,
#  'lame so': 11118,
#  'so dull': 17655,
#  'dull and': 5855,
#  'and so': 1274,
#  'so devoid': 17651,
#  'devoid of': 5343,
#  'of any': 13701,
#  'any excitement': 1483,
#  'excitement or': 6475,
#  'or intelligence': 14376,
#  'intelligence you': 9937,
#  'you ll': 23300,
#  'll think': 11631,
#  'think the': 20127,
#  'the screenwriters': 19635,
#  'screenwriters didn': 16798,
#  'with it': 22826,
#  'it and': 10410,
#  'and got': 1092,
#  'got bored': 8025,
#  'bored trying': 3006,
#  'trying what': 21074,
#  'what sorry': 22368,
#  'sorry waste': 17873,
#  'waste of': 22046,
#  'of good': 13795,
#  'good idea': 7988,
#  'been': 2551,
#  'episode': 6243,
#  'simply': 17476,
#  'had': 8202,
#  'off': 13987,
#  'representation': 16143,
#  'horrible': 9241,
#  'makers': 12011,
#  'ever': 6373,
#  'set': 17093,
#  'foot': 7221,
#  'britain': 3284,
#  'prior': 15450,
#  'england': 6149,
#  'don': 5730,
#  'person': 14906,
#  'such': 18404,
#  'accent': 254,
#  'apart': 1545,
#  ...}

# %% [markdown]
# Now we have a vectorizer that can produce representations including bigrams. Let's apply it to the text to get an expanded term-document matrix:

# %%
bigram_doc_mat = bigram_vectorizer.transform(input_text).T
print("The shape of the bigram document-term matrix is: ", bigram_doc_mat.shape)
# Out:
# The shape of the bigram document-term matrix is:  (23391, 100)

# %% [markdown]
# # OPTIONAL:
#
# This part aims to give you some more understanding of bigrams and n-grams in general, and shows you how to use the lemmatizer with the CountVectorizer class. It is not required to do this part, and we will revisit the use of n-grams and lemmatizers in the later lab on classifiers.
#
# The code below chooses a document that we can experiment with.
#
# **TO-DO 11:** Find the top three documents that are most similar to `selected_doc` when using vectors of bigrams+unigrams. Print them out. Hint: numpy contains useful functions such as argsort, for sorting a list or array.
#
# **TO-DO 12:** Repeat the process with the pure unigram bag of words representations. Does the list change? Can you see why it may be different?
#
# **TO-DO 13:** Experiment with other choices of `selected_doc` and increasing the length of the features bigrams to trigrams and other lengths of n-gram.

# %%
selected_doc = 1
scores = []

print(input_text[selected_doc])  # print the document we're using as our query
print("\n")

### WRITE YOUR OWN CODE HERE
# Out:
# VAMPYRES <br /><br />Aspect ratio: 1.85:1<br /><br />Sound format: Mono<br /><br />A motorist (Murray Brown) is lured to an isolated country house inhabited by two beautiful young women (Marianne Morris and Anulka) and becomes enmeshed in their free-spirited sexual lifestyle, but his hosts turn out to be vampires with a frenzied lust for human blood...<br /><br />Taking its cue from the lesbian vampire cycle initiated by maverick director Jean Rollin in France, and consolidated by the success of Hammer's "Carmilla" series in the UK, Jose Ramon Larraz' daring shocker VAMPYRES pushed the concept of Adult Horror much further than British censors were prepared to tolerate in 1974, and his film was cut by almost three minutes on its original British release. It isn't difficult to see why! Using its Gothic theme as the pretext for as much nudity, sex and bloodshed as the film's short running time will allow, Larraz (who wrote the screenplay under the pseudonym 'D. Daubeney') uses these commercial elements as mere backdrop to a languid meditation on life, death and the impulses - sexual and otherwise - which affirm the human condition.<br /><br />Shot on location at a picturesque country house during the Autumn of 1973, Harry Waxman's haunting cinematography conjures an atmosphere of grim foreboding, in which the desolate countryside - bleak and beautiful in equal measure - seems to foreshadow a whirlwind of impending horror (Larraz pulled a similar trick earlier the same year with SYMPTOMS, a low-key thriller which erupts into a frenzy of violence during the final reel). However, despite its pretensions, VAMPYRES' wafer-thin plot and rough-hewn production values will divide audiences from the outset, and while the two female protagonists are as charismatic and appealing as could be wished, the male lead (Brown, past his prime at the time of filming) is woefully miscast in a role that should have gone to some beautiful twentysomething stud. A must-see item for cult movie fans, an amusing curio for everyone else, VAMPYRES is an acquired taste. Watch out for silent era superstar Bessie Love in a brief cameo at the end of the movie.

# %% [markdown]
# The vocabulary size is probably getting very large, now that we are using bigrams and other n-grams.
#
# To apply lemmatization, we have to go back to the CountVectorizer and define a new tokenizer class that will carry out the extra step of lemmatization. The code below shows how to apply lemmatization with the CountVectorizer class to reduce the vocabulary size.

# %%
class LemmaTokenizer(object):  # this 'tokenizer' will also do additional preprocessing steps, namely, lemmatize verbs and adjectives
    
    def __init__(self):
        self.wnl = nltk.WordNetLemmatizer()
        
    def __call__(self, docs):
        return [self.wnl.lemmatize(self.wnl.lemmatize(tok, pos='v'), pos='a') for tok in nltk.word_tokenize(docs)]
    
lemm_vectorizer = CountVectorizer(tokenizer=LemmaTokenizer(), ngram_range=(1,2), token_pattern=None)  # include bigrams as well as unigrams

lemm_vectorizer.fit(input_text)
lemm_term_doc_mat = lemm_vectorizer.transform(input_text).T

# Print out some of the features in the vocabulary:
print(list(vectorizer.vocabulary_))
# Out:
# ['didn', 'care', 'for', 'the', 'movie', 'book', 'was', 'better', 'does', 'anyone', 'know', 'where', 'it', 'filmed', 'this', 'my', 'first', 'visit', 'to', 'your', 'site', 'just', 'found', 'answer', 'question', 'so', 'now', 'look', 'like', 'dummy', 'but', 'think', 'll', 'still', 'submit', 'comments', 'and', 'yes', 'british', 'columbia', 'is', 'lovely', 'or', 'why', 'they', 'took', 'from', 'its', 'south', 'carolina', 'coastal', 'setting', 'stands', 'place', 'essential', 'fabric', 'of', 'change', 'part', 'disappointment', 'with', 'oh', 'read', 'need', 'write', 'at', 'least', 'ten', 'lines', 'here', 'other', 'main', 'issue', 'film', 'kim', 'bassinger', 'too', 'vapid', 'not', 'all', 'what', 'pictured', 'well', 'good', 'character', 'in', 'much', 'more', 'empathetic', 'also', 'evoked', 'rustic', 'almost', 'primitive', 'images', 'monastery', 'while', 'castle', 'visually', 'impressive', 'distorted', 'feel', 'story', 'seemed', 'odds', 'characters', 'vampyres', 'br', 'aspect', 'ratio', '85', 'sound', 'format', 'mono', 'motorist', 'murray', 'brown', 'lured', 'an', 'isolated', 'country', 'house', 'inhabited', 'by', 'two', 'beautiful', 'young', 'women', 'marianne', 'morris', 'anulka', 'becomes', 'enmeshed', 'their', 'free', 'spirited', 'sexual', 'lifestyle', 'his', 'hosts', 'turn', 'out', 'be', 'vampires', 'frenzied', 'lust', 'human', 'blood', 'taking', 'cue', 'lesbian', 'vampire', 'cycle', 'initiated', 'maverick', 'director', 'jean', 'rollin', 'france', 'consolidated', 'success', 'hammer', 'carmilla', 'series', 'uk', 'jose', 'ramon', 'larraz', 'daring', 'shocker', 'pushed', 'concept', 'adult', 'horror', 'further', 'than', 'censors', 'were', 'prepared', 'tolerate', '1974', 'cut', 'three', 'minutes', 'on', 'original', 'release', 'isn', 'difficult', 'see', 'using', 'gothic', 'theme', 'as', 'pretext', 'nudity', 'sex', 'bloodshed', 'short', 'running', 'time', 'will', 'allow', 'who', 'wrote', 'screenplay', 'under', 'pseudonym', 'daubeney', 'uses', 'these', 'commercial', 'elements', 'mere', 'backdrop', 'languid', 'meditation', 'life', 'death', 'impulses', 'otherwise', 'which', 'affirm', 'condition', 'shot', 'location', 'picturesque', 'during', 'autumn', '1973', 'harry', 'waxman', 'haunting', 'cinematography', 'conjures', 'atmosphere', 'grim', 'foreboding', 'desolate', 'countryside', 'bleak', 'equal', 'measure', 'seems', 'foreshadow', 'whirlwind', 'impending', 'pulled', 'similar', 'trick', 'earlier', 'same', 'year', 'symptoms', 'low', 'key', 'thriller', 'erupts', 'into', 'frenzy', 'violence', 'final', 'reel', 'however', 'despite', 'pretensions', 'wafer', 'thin', 'plot', 'rough', 'hewn', 'production', 'values', 'divide', 'audiences', 'outset', 'female', 'protagonists', 'are', 'charismatic', 'appealing', 'could', 'wished', 'male', 'lead', 'past', 'prime', 'filming', 'woefully', 'miscast', 'role', 'that', 'should', 'have', 'gone', 'some', 'twentysomething', 'stud', 'must', 'item', 'cult', 'fans', 'amusing', 'curio', 'everyone', 'else', 'acquired', 'taste', 'watch', 'silent', 'era', 'superstar', 'bessie', 'love', 'brief', 'cameo', 'end', 'interesting', 'naive', 'park', 'ranger', 'colin', 'firth', 'marries', 'pretty', 'mysterious', 'woman', 'lisa', 'zane', 'he', 'only', 'known', 'seem', 'happy', 'then', 'she', 'disappears', 'without', 'warning', 'searches', 'her', 'after', 'few', 'dead', 'ends', 'stumbles', 'upon', 'abused', 'childhood', 'sleazy', 'recent', 'may', 'include', 'criminal', 'activity', 'filmmakers', 'do', 'beginning', 'suspenseful', 'sounds', 'watchable', 'ceases', 'even', 'make', 'sense', 'ending', 'lame', 'dull', 'devoid', 'any', 'excitement', 'intelligence', 'you', 'screenwriters', 'got', 'bored', 'trying', 'sorry', 'waste', 'idea', 'been', 'episode', 'simply', 'had', 'off', 'representation', 'horrible', 'makers', 'ever', 'set', 'foot', 'britain', 'prior', 'england', 'don', 'person', 'such', 'accent', 'apart', 'comedy', 'skit', 'royal', 'family', 'english', 'boys', 'boy', 'has', 'acted', 'spoke', 'dressed', 'kid', 'history', 'nation', 's ...

# %%
print(f'Vocabulary size: {len(vectorizer.vocabulary_)}')
print(f'Size of term document matrix with lemmatization: {lemm_term_doc_mat.shape}')
# Out:
# Vocabulary size: 4945
# Size of term document matrix with lemmatization: (23100, 100)

# %% [markdown]
# **TO-DO 14:** Run the code below and compare with your previous results. Print out the vocabulary to see how the lemmatizer has changed the results. You can also experiment with the 'pos' parameter to lemmatise different categories of word (verbs, adjectives, nouns).

# %%
### WRITE YOUR OWN CODE HERE
